# %% [markdown]
# # PostgreSQL Languages AST parser

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import pglast

# %% [markdown]
# ## SELECT

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT foo FROM bar")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'foo'}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'bar',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 16}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT b.foo FROM bar b")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'b'}},
#            {'String': {'sval': 'foo'}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'bar',
#         'inh': True,
#         'relpersistence': 'p',
#         'alias': {'aliasname': 'b'},
#         'location': 18}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id AS i FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'name': 'i',
#         'val': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 20}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id AS i, key AS k FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'name': 'i',
#         'val': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#           'location': 7}},
#         'location': 7}},
#       {'ResTarget': {'name': 'k',
#         'val': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#           'location': 16}},
#         'location': 16}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 30}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT MIN(id) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'min'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 11}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 20}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id + (SELECT MIN(id) FROM foo) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '+'}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 7}},
#           'rexpr': {'SubLink': {'subLinkType': 'EXPR_SUBLINK',
#             'subselect': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'min'}}],
#                    'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#                       'location': 24}}],
#                    'funcformat': 'COERCE_EXPLICIT_CALL',
#                    'location': 20}},
#                  'location': 20}}],
#               'fromClause': [{'RangeVar': {'relname': 'foo',
#                  'inh': True,
#                  'relpersistence': 'p',
#                  'location': 33}}],
#               'limitOption': 'LIMIT_OPTION_DEFAULT',
#               'op': 'SETOP_NONE'}},
#             'location': 12}},
#           'location': 10}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 43}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT DISTINCT id FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'distinctClause': [{}],
#      'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#           'location': 16}},
#         'location': 16}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 24}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT MIN(id) AS m FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'name': 'm',
#         'val': {'FuncCall': {'funcname': [{'String': {'sval': 'min'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 11}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 25}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT COUNT(DISTINCT id), MIN(id) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'count'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 22}}],
#           'agg_distinct': True,
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}},
#       {'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'min'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 31}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 27}},
#         'location': 27}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 40}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT NULL")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Const': {'isnull': True,
#           'location': 7}},
#         'location': 7}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Basic predicates

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE 42")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Const': {'ival': {'ival': 42}, 'location': 24}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo, bar WHERE id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'RangeVar': {'relname': 'bar',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 19}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 29}},
#        'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#          'location': 34}},
#        'location': 32}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo, bar WHERE id != fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'RangeVar': {'relname': 'bar',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 19}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '<>'}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 29}},
#        'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#          'location': 35}},
#        'location': 32}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id = 'bar'")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'rexpr': {'A_Const': {'sval': {'sval': 'bar'}, 'location': 29}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id LIKE 'bar'")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_LIKE',
#        'name': [{'String': {'sval': '~~'}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'rexpr': {'A_Const': {'sval': {'sval': 'bar'}, 'location': 32}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id NOT LIKE 'bar'")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_LIKE',
#        'name': [{'String': {'sval': '!~~'}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'rexpr': {'A_Const': {'sval': {'sval': 'bar'}, 'location': 36}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id < '1990-01-10'")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '<'}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'rexpr': {'A_Const': {'sval': {'sval': '1990-01-10'}, 'location': 29}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id = 42")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 29}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Compound predicates

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id = 42 AND key = 'bar'")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'BoolExpr': {'boolop': 'AND_EXPR',
#        'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 24}},
#           'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 29}},
#           'location': 27}},
#         {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#             'location': 36}},
#           'rexpr': {'A_Const': {'sval': {'sval': 'bar'}, 'location': 42}},
#           'location': 40}}],
#        'location': 32}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id = 42 OR key = 'bar'")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'BoolExpr': {'boolop': 'OR_EXPR',
#        'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 24}},
#           'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 29}},
#           'location': 27}},
#         {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#             'location': 35}},
#           'rexpr': {'A_Const': {'sval': {'sval': 'bar'}, 'location': 41}},
#           'location': 39}}],
#        'location': 32}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id = 42 AND (key = 'bar' OR key = 'baz')")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'BoolExpr': {'boolop': 'AND_EXPR',
#        'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 24}},
#           'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 29}},
#           'location': 27}},
#         {'BoolExpr': {'boolop': 'OR_EXPR',
#           'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#              'name': [{'String': {'sval': '='}}],
#              'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#                'location': 37}},
#              'rexpr': {'A_Const': {'sval': {'sval': 'bar'}, 'location': 43}},
#              'location': 41}},
#            {'A_Expr': {'kind': 'AEXPR_OP',
#              'name': [{'String': {'sval': '='}}],
#              'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#                'location': 52}},
#              'rexpr': {'A_Const': {'sval': {'sval': 'baz'}, 'location': 58}},
#              'location': 56}}],
#           'location': 49}}],
#        'location': 32}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id = 42 AND NOT (key = 'bar' OR key = 'baz')")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'BoolExpr': {'boolop': 'AND_EXPR',
#        'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 24}},
#           'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 29}},
#           'location': 27}},
#         {'BoolExpr': {'boolop': 'NOT_EXPR',
#           'args': [{'BoolExpr': {'boolop': 'OR_EXPR',
#              'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#                 'name': [{'String': {'sval': '='}}],
#                 'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#                   'location': 41}},
#                 'rexpr': {'A_Const': {'sval': {'sval': 'bar'},
#                   'location': 47}},
#                 'location': 45}},
#               {'A_Expr': {'kind': 'AEXPR_OP',
#                 'name': [{'String': {'sval': '='}}],
#                 'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#                   'location': 56}},
#                 'rexpr': {'A_Const': {'sval': {'sval': 'baz'},
#                   'location': 62}},
#                 'location': 60}}],
#              'location': 53}}],
#           'location': 36}}],
#        'location': 32}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Aliases

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo f, bar b WHERE f.id = b.fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'alias': {'aliasname': 'f'},
#         'location': 14}},
#       {'RangeVar': {'relname': 'bar',
#         'inh': True,
#         'relpersistence': 'p',
#         'alias': {'aliasname': 'b'},
#         'location': 21}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'f'}},
#           {'String': {'sval': 'id'}}],
#          'location': 33}},
#        'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'b'}},
#           {'String': {'sval': 'fkey'}}],
#          'location': 40}},
#        'location': 38}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Subqueries

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id IN (SELECT fkey FROM bar)")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'SubLink': {'subLinkType': 'ANY_SUBLINK',
#        'testexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'subselect': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#               'location': 38}},
#             'location': 38}}],
#          'fromClause': [{'RangeVar': {'relname': 'bar',
#             'inh': True,
#             'relpersistence': 'p',
#             'location': 48}}],
#          'limitOption': 'LIMIT_OPTION_DEFAULT',
#          'op': 'SETOP_NONE'}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo, (SELECT * FROM bar WHERE bar_id < 42) WHERE foo_id != bar_id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'RangeSubselect': {'subquery': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#                'location': 27}},
#              'location': 27}}],
#           'fromClause': [{'RangeVar': {'relname': 'bar',
#              'inh': True,
#              'relpersistence': 'p',
#              'location': 34}}],
#           'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#             'name': [{'String': {'sval': '<'}}],
#             'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'bar_id'}}],
#               'location': 44}},
#             'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 53}},
#             'location': 51}},
#           'limitOption': 'LIMIT_OPTION_DEFAULT',
#           'op': 'SETOP_NONE'}}}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '<>'}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'foo_id'}}],
#          'location': 63}},
#        'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'bar_id'}}],
#          'location': 73}},
#        'location': 70}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo, (SELECT * FROM bar WHERE bar_id < 42) AS b WHERE foo_id != bar_id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'RangeSubselect': {'subquery': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#                'location': 27}},
#              'location': 27}}],
#           'fromClause': [{'RangeVar': {'relname': 'bar',
#              'inh': True,
#              'relpersistence': 'p',
#              'location': 34}}],
#           'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#             'name': [{'String': {'sval': '<'}}],
#             'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'bar_id'}}],
#               'location': 44}},
#             'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 53}},
#             'location': 51}},
#           'limitOption': 'LIMIT_OPTION_DEFAULT',
#           'op': 'SETOP_NONE'}},
#         'alias': {'aliasname': 'b'}}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '<>'}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'foo_id'}}],
#          'location': 68}},
#        'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'bar_id'}}],
#          'location': 78}},
#        'location': 75}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Special predicates

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo, bar WHERE id IN ('bar', 'baz')")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'RangeVar': {'relname': 'bar',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 19}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_IN',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 29}},
#        'rexpr': {'List': {'items': [{'A_Const': {'sval': {'sval': 'bar'},
#             'location': 36}},
#           {'A_Const': {'sval': {'sval': 'baz'}, 'location': 43}}]}},
#        'location': 32}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id IN ('bar', (SELECT MIN(fkey) FROM bar))")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_IN',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'rexpr': {'List': {'items': [{'A_Const': {'sval': {'sval': 'bar'},
#             'location': 31}},
#           {'SubLink': {'subLinkType': 'EXPR_SUBLINK',
#             'subselect': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'min'}}],
#                    'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#                       'location': 50}}],
#                    'funcformat': 'COERCE_EXPLICIT_CALL',
#                    'location': 46}},
#                  'location': 46}}],
#               'fromClause': [{'RangeVar': {'relname': 'bar',
#                  'inh': True,
#                  'relpersistence': 'p',
#                  'location': 61}}],
#               'limitOption': 'LIMIT_OPTION_DEFAULT',
#               'op': 'SETOP_NONE'}},
#             'location': 38}}]}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo, bar WHERE id IN ('bar', bar.id, 'biz')")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'RangeVar': {'relname': 'bar',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 19}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_IN',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 29}},
#        'rexpr': {'List': {'items': [{'A_Const': {'sval': {'sval': 'bar'},
#             'location': 36}},
#           {'ColumnRef': {'fields': [{'String': {'sval': 'bar'}},
#              {'String': {'sval': 'id'}}],
#             'location': 43}},
#           {'A_Const': {'sval': {'sval': 'biz'}, 'location': 51}}]}},
#        'location': 32}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id IN (SELECT id FROM bar)")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'SubLink': {'subLinkType': 'ANY_SUBLINK',
#        'testexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'subselect': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#               'location': 38}},
#             'location': 38}}],
#          'fromClause': [{'RangeVar': {'relname': 'bar',
#             'inh': True,
#             'relpersistence': 'p',
#             'location': 46}}],
#          'limitOption': 'LIMIT_OPTION_DEFAULT',
#          'op': 'SETOP_NONE'}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id BETWEEN 24 AND 42")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_BETWEEN',
#        'name': [{'String': {'sval': 'BETWEEN'}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'rexpr': {'List': {'items': [{'A_Const': {'ival': {'ival': 24},
#             'location': 35}},
#           {'A_Const': {'ival': {'ival': 42}, 'location': 42}}]}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id IS NOT NULL")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'NullTest': {'arg': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'nulltesttype': 'IS_NOT_NULL',
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id IS NULL")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'NullTest': {'arg': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'nulltesttype': 'IS_NULL',
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Advanced value manipulations

# %%
parse_tree = parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id = CURRENT_DATE")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 24}},
#        'rexpr': {'SQLValueFunction': {'op': 'SVFOP_CURRENT_DATE',
#          'typmod': -1,
#          'location': 29}},
#        'location': 27}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo WHERE id + '5 days'::interval = 42")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'A_Expr': {'kind': 'AEXPR_OP',
#          'name': [{'String': {'sval': '+'}}],
#          'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#            'location': 24}},
#          'rexpr': {'TypeCast': {'arg': {'A_Const': {'sval': {'sval': '5 days'},
#              'location': 29}},
#            'typeName': {'names': [{'String': {'sval': 'pg_catalog'}},
#              {'String': {'sval': 'interval'}}],
#             'typemod': -1,
#             'location': 39},
#            'location': 37}},
#          'location': 27}},
#        'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 50}},
#        'location': 48}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id::interval FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'TypeCast': {'arg': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 7}},
#           'typeName': {'names': [{'String': {'sval': 'pg_catalog'}},
#             {'String': {'sval': 'interval'}}],
#            'typemod': -1,
#            'location': 11},
#           'location': 9}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 25}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT CASE WHEN R.a = 42 THEN 'a' END FROM R")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'CaseExpr': {'args': [{'CaseWhen': {'expr': {'A_Expr': {'kind': 'AEXPR_OP',
#                'name': [{'String': {'sval': '='}}],
#                'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#                   {'String': {'sval': 'a'}}],
#                  'location': 17}},
#                'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 23}},
#                'location': 21}},
#              'result': {'A_Const': {'sval': {'sval': 'a'}, 'location': 31}},
#              'location': 12}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 44}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT 'prefix' || R.a FROM R")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '||'}}],
#           'lexpr': {'A_Const': {'sval': {'sval': 'prefix'}, 'location': 7}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#              {'String': {'sval': 'a'}}],
#             'location': 19}},
#           'location': 16}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 28}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT my_udf(R.a = S.b) FROM R, S")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'my_udf'}}],
#           'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#              'name': [{'String': {'sval': '='}}],
#              'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#                 {'String': {'sval': 'a'}}],
#                'location': 14}},
#              'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 's'}},
#                 {'String': {'sval': 'b'}}],
#                'location': 20}},
#              'location': 18}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 30}},
#       {'RangeVar': {'relname': 's',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 33}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## CASE Expressions

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT CASE WHEN R.a = 42 THEN 'a' ELSE 'b' END FROM R")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'CaseExpr': {'args': [{'CaseWhen': {'expr': {'A_Expr': {'kind': 'AEXPR_OP',
#                'name': [{'String': {'sval': '='}}],
#                'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#                   {'String': {'sval': 'a'}}],
#                  'location': 17}},
#                'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 23}},
#                'location': 21}},
#              'result': {'A_Const': {'sval': {'sval': 'a'}, 'location': 31}},
#              'location': 12}}],
#           'defresult': {'A_Const': {'sval': {'sval': 'b'}, 'location': 40}},
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 53}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT CASE WHEN R.a = 42 THEN 'a' WHEN R.a > 42 THEN 'b' ELSE 'c' END FROM R")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'CaseExpr': {'args': [{'CaseWhen': {'expr': {'A_Expr': {'kind': 'AEXPR_OP',
#                'name': [{'String': {'sval': '='}}],
#                'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#                   {'String': {'sval': 'a'}}],
#                  'location': 17}},
#                'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 23}},
#                'location': 21}},
#              'result': {'A_Const': {'sval': {'sval': 'a'}, 'location': 31}},
#              'location': 12}},
#            {'CaseWhen': {'expr': {'A_Expr': {'kind': 'AEXPR_OP',
#                'name': [{'String': {'sval': '>'}}],
#                'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#                   {'String': {'sval': 'a'}}],
#                  'location': 40}},
#                'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 46}},
#                'location': 44}},
#              'result': {'A_Const': {'sval': {'sval': 'b'}, 'location': 54}},
#              'location': 35}}],
#           'defresult': {'A_Const': {'sval': {'sval': 'c'}, 'location': 63}},
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 76}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT CASE R.a WHEN  42 THEN 'a' WHEN 24 THEN 'b' ELSE 'c' END FROM R")
json.loads(parse_tree)["stmts"][0]["stmt"]["SelectStmt"]["targetList"][0]["ResTarget"]["val"]["CaseExpr"]
# Out:
# {'arg': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#     {'String': {'sval': 'a'}}],
#    'location': 12}},
#  'args': [{'CaseWhen': {'expr': {'A_Const': {'ival': {'ival': 42},
#       'location': 22}},
#     'result': {'A_Const': {'sval': {'sval': 'a'}, 'location': 30}},
#     'location': 16}},
#   {'CaseWhen': {'expr': {'A_Const': {'ival': {'ival': 24}, 'location': 39}},
#     'result': {'A_Const': {'sval': {'sval': 'b'}, 'location': 47}},
#     'location': 34}}],
#  'defresult': {'A_Const': {'sval': {'sval': 'c'}, 'location': 56}},
#  'location': 7}

# %% [markdown]
# ## SELECT ... FROM ... JOIN ...

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo JOIN bar ON id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 23}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 30}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#             'location': 35}},
#           'location': 33}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo f JOIN bar b ON f.id = b.fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'alias': {'aliasname': 'f'},
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'alias': {'aliasname': 'b'},
#           'location': 25}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'f'}},
#              {'String': {'sval': 'id'}}],
#             'location': 34}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'b'}},
#              {'String': {'sval': 'fkey'}}],
#             'location': 41}},
#           'location': 39}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo JOIN bar ON id = fkey AND id = 'baz'")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 23}},
#         'quals': {'BoolExpr': {'boolop': 'AND_EXPR',
#           'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#              'name': [{'String': {'sval': '='}}],
#              'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#                'location': 30}},
#              'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#                'location': 35}},
#              'location': 33}},
#            {'A_Expr': {'kind': 'AEXPR_OP',
#              'name': [{'String': {'sval': '='}}],
#              'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#                'location': 44}},
#              'rexpr': {'A_Const': {'sval': {'sval': 'baz'}, 'location': 49}},
#              'location': 47}}],
#           'location': 40}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo JOIN (SELECT * FROM bar) bar2 ON id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeSubselect': {'subquery': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#                  'location': 31}},
#                'location': 31}}],
#             'fromClause': [{'RangeVar': {'relname': 'bar',
#                'inh': True,
#                'relpersistence': 'p',
#                'location': 38}}],
#             'limitOption': 'LIMIT_OPTION_DEFAULT',
#             'op': 'SETOP_NONE'}},
#           'alias': {'aliasname': 'bar2'}}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 51}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#             'location': 56}},
#           'location': 54}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo CROSS JOIN bar")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 29}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo FULL JOIN bar ON id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_FULL',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 28}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 35}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#             'location': 40}},
#           'location': 38}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo LEFT JOIN bar ON id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_LEFT',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 28}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 35}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#             'location': 40}},
#           'location': 38}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo FULL OUTER JOIN bar ON id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_FULL',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 34}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 41}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#             'location': 46}},
#           'location': 44}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo RIGHT OUTER JOIN bar ON id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_RIGHT',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 35}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 42}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#             'location': 47}},
#           'location': 45}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo INNER JOIN bar ON id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 29}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 36}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#             'location': 41}},
#           'location': 39}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo NATURAL JOIN bar")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'isNatural': True,
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 31}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo JOIN bar USING (id)")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 23}},
#         'usingClause': [{'String': {'sval': 'id'}}]}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo JOIN bar USING (id, fkey)")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 23}},
#         'usingClause': [{'String': {'sval': 'id'}},
#          {'String': {'sval': 'fkey'}}]}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo JOIN (bar JOIN baz ON a = b) ON c = d")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 14}},
#         'rarg': {'JoinExpr': {'jointype': 'JOIN_INNER',
#           'larg': {'RangeVar': {'relname': 'bar',
#             'inh': True,
#             'relpersistence': 'p',
#             'location': 24}},
#           'rarg': {'RangeVar': {'relname': 'baz',
#             'inh': True,
#             'relpersistence': 'p',
#             'location': 33}},
#           'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#             'name': [{'String': {'sval': '='}}],
#             'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'a'}}],
#               'location': 40}},
#             'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'b'}}],
#               'location': 44}},
#             'location': 42}}}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'c'}}],
#             'location': 50}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'd'}}],
#             'location': 54}},
#           'location': 52}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Advanced FROM clause / JOIN combinations

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM R, S s JOIN R1 ON R.id = R1.id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 's',
#           'inh': True,
#           'relpersistence': 'p',
#           'alias': {'aliasname': 's'},
#           'location': 17}},
#         'rarg': {'RangeVar': {'relname': 'r1',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 26}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#              {'String': {'sval': 'id'}}],
#             'location': 32}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r1'}},
#              {'String': {'sval': 'id'}}],
#             'location': 39}},
#           'location': 37}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM R, S s JOIN R1 r1 ON R.id = R1.id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 's',
#           'inh': True,
#           'relpersistence': 'p',
#           'alias': {'aliasname': 's'},
#           'location': 17}},
#         'rarg': {'RangeVar': {'relname': 'r1',
#           'inh': True,
#           'relpersistence': 'p',
#           'alias': {'aliasname': 'r1'},
#           'location': 26}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#              {'String': {'sval': 'id'}}],
#             'location': 35}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r1'}},
#              {'String': {'sval': 'id'}}],
#             'location': 42}},
#           'location': 40}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM R, S s JOIN (SELECT * FROM R1) ON R.id = R1.id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 's',
#           'inh': True,
#           'relpersistence': 'p',
#           'alias': {'aliasname': 's'},
#           'location': 17}},
#         'rarg': {'RangeSubselect': {'subquery': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#                  'location': 34}},
#                'location': 34}}],
#             'fromClause': [{'RangeVar': {'relname': 'r1',
#                'inh': True,
#                'relpersistence': 'p',
#                'location': 41}}],
#             'limitOption': 'LIMIT_OPTION_DEFAULT',
#             'op': 'SETOP_NONE'}}}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#              {'String': {'sval': 'id'}}],
#             'location': 48}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r1'}},
#              {'String': {'sval': 'id'}}],
#             'location': 55}},
#           'location': 53}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM R, S s JOIN (SELECT * FROM R1) r1 ON R.id = R1.id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}},
#       {'JoinExpr': {'jointype': 'JOIN_INNER',
#         'larg': {'RangeVar': {'relname': 's',
#           'inh': True,
#           'relpersistence': 'p',
#           'alias': {'aliasname': 's'},
#           'location': 17}},
#         'rarg': {'RangeSubselect': {'subquery': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#                  'location': 34}},
#                'location': 34}}],
#             'fromClause': [{'RangeVar': {'relname': 'r1',
#                'inh': True,
#                'relpersistence': 'p',
#                'location': 41}}],
#             'limitOption': 'LIMIT_OPTION_DEFAULT',
#             'op': 'SETOP_NONE'}},
#           'alias': {'aliasname': 'r1'}}},
#         'quals': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#              {'String': {'sval': 'id'}}],
#             'location': 51}},
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'r1'}},
#              {'String': {'sval': 'id'}}],
#             'location': 58}},
#           'location': 56}}}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## EXPLAIN

# %%
parse_tree = pglast.parser.parse_sql_json("EXPLAIN SELECT * FROM foo, bar WHERE id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'ExplainStmt': {'query': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#             'location': 15}},
#           'location': 15}}],
#        'fromClause': [{'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 22}},
#         {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 27}}],
#        'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#          'name': [{'String': {'sval': '='}}],
#          'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#            'location': 37}},
#          'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#            'location': 42}},
#          'location': 40}},
#        'limitOption': 'LIMIT_OPTION_DEFAULT',
#        'op': 'SETOP_NONE'}}}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("EXPLAIN (ANALYZE, FORMAT JSON) SELECT * FROM foo, bar WHERE id = fkey")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'ExplainStmt': {'query': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#             'location': 38}},
#           'location': 38}}],
#        'fromClause': [{'RangeVar': {'relname': 'foo',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 45}},
#         {'RangeVar': {'relname': 'bar',
#           'inh': True,
#           'relpersistence': 'p',
#           'location': 50}}],
#        'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#          'name': [{'String': {'sval': '='}}],
#          'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#            'location': 60}},
#          'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#            'location': 65}},
#          'location': 63}},
#        'limitOption': 'LIMIT_OPTION_DEFAULT',
#        'op': 'SETOP_NONE'}},
#      'options': [{'DefElem': {'defname': 'analyze',
#         'defaction': 'DEFELEM_UNSPEC',
#         'location': 9}},
#       {'DefElem': {'defname': 'format',
#         'arg': {'String': {'sval': 'json'}},
#         'defaction': 'DEFELEM_UNSPEC',
#         'location': 18}}]}}}]}

# %% [markdown]
# ## Mathematics

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id + 5 FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '+'}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 7}},
#           'rexpr': {'A_Const': {'ival': {'ival': 5}, 'location': 12}},
#           'location': 10}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 19}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id - 5 FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '-'}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 7}},
#           'rexpr': {'A_Const': {'ival': {'ival': 5}, 'location': 12}},
#           'location': 10}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 19}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id * 2 FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '*'}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 7}},
#           'rexpr': {'A_Const': {'ival': {'ival': 2}, 'location': 12}},
#           'location': 10}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 19}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id / 1000 FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '/'}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 7}},
#           'rexpr': {'A_Const': {'ival': {'ival': 1000}, 'location': 12}},
#           'location': 10}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 22}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT id % 2 FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '%'}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 7}},
#           'rexpr': {'A_Const': {'ival': {'ival': 2}, 'location': 12}},
#           'location': 10}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 19}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT -id FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '-'}}],
#           'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 8}},
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 16}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Aggregate Functions

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT COUNT(*) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'count'}}],
#           'agg_star': True,
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 21}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT COUNT(id) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'count'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 13}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 22}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT AVG(id) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'avg'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 11}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 20}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT AVG('bar') FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'avg'}}],
#           'args': [{'A_Const': {'sval': {'sval': 'bar'}, 'location': 11}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 23}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT MIN(id) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'min'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 11}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 20}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT MAX(id) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'max'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 11}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 20}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT SUM(id) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'sum'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 11}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 20}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Function calls

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT CURRENT_DATE FROM foo WHERE UPPER(id) = id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'SQLValueFunction': {'op': 'SVFOP_CURRENT_DATE',
#           'typmod': -1,
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 25}}],
#      'whereClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'FuncCall': {'funcname': [{'String': {'sval': 'upper'}}],
#          'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 41}}],
#          'funcformat': 'COERCE_EXPLICIT_CALL',
#          'location': 35}},
#        'rexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#          'location': 47}},
#        'location': 45}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT SOUNDEX(UPPER('id'))")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'soundex'}}],
#           'args': [{'FuncCall': {'funcname': [{'String': {'sval': 'upper'}}],
#              'args': [{'A_Const': {'sval': {'sval': 'id'}, 'location': 21}}],
#              'funcformat': 'COERCE_EXPLICIT_CALL',
#              'location': 15}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT REPEAT('id', 5)")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'repeat'}}],
#           'args': [{'A_Const': {'sval': {'sval': 'id'}, 'location': 14}},
#            {'A_Const': {'ival': {'ival': 5}, 'location': 20}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT UPPER(id) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'upper'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#              'location': 13}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 22}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT LOWER(id OR key OR fkey) FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'lower'}}],
#           'args': [{'BoolExpr': {'boolop': 'OR_EXPR',
#              'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#                 'location': 13}},
#               {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#                 'location': 19}},
#               {'ColumnRef': {'fields': [{'String': {'sval': 'fkey'}}],
#                 'location': 26}}],
#              'location': 16}}],
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 37}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## GROUP BY, ORDER BY, HAVING, LIMIT

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo GROUP BY id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'groupClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#         'location': 27}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo GROUP BY id, key")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'groupClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#         'location': 27}},
#       {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#         'location': 31}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo GROUP BY ALL id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'groupClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#         'location': 31}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo GROUP BY DISTINCT id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'groupClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#         'location': 36}}],
#      'groupDistinct': True,
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo GROUP BY DISTINCT id, key")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'groupClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#         'location': 36}},
#       {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#         'location': 40}}],
#      'groupDistinct': True,
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo GROUP BY id HAVING SUM(id) = 42")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'groupClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#         'location': 27}}],
#      'havingClause': {'A_Expr': {'kind': 'AEXPR_OP',
#        'name': [{'String': {'sval': '='}}],
#        'lexpr': {'FuncCall': {'funcname': [{'String': {'sval': 'sum'}}],
#          'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 41}}],
#          'funcformat': 'COERCE_EXPLICIT_CALL',
#          'location': 37}},
#        'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 47}},
#        'location': 45}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo GROUP BY id HAVING SUM(id) = 42 AND id = 1")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'groupClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#         'location': 27}}],
#      'havingClause': {'BoolExpr': {'boolop': 'AND_EXPR',
#        'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'FuncCall': {'funcname': [{'String': {'sval': 'sum'}}],
#             'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#                'location': 41}}],
#             'funcformat': 'COERCE_EXPLICIT_CALL',
#             'location': 37}},
#           'rexpr': {'A_Const': {'ival': {'ival': 42}, 'location': 47}},
#           'location': 45}},
#         {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '='}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#             'location': 54}},
#           'rexpr': {'A_Const': {'ival': {'ival': 1}, 'location': 59}},
#           'location': 57}}],
#        'location': 50}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo ORDER BY id")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'sortClause': [{'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#           'location': 27}},
#         'sortby_dir': 'SORTBY_DEFAULT',
#         'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#         'location': -1}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo ORDER BY id DESC")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'sortClause': [{'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#           'location': 27}},
#         'sortby_dir': 'SORTBY_DESC',
#         'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#         'location': -1}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo ORDER BY id, key")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'sortClause': [{'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#           'location': 27}},
#         'sortby_dir': 'SORTBY_DEFAULT',
#         'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#         'location': -1}},
#       {'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#           'location': 31}},
#         'sortby_dir': 'SORTBY_DEFAULT',
#         'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#         'location': -1}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo ORDER BY id DESC, key ASC")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'sortClause': [{'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'id'}}],
#           'location': 27}},
#         'sortby_dir': 'SORTBY_DESC',
#         'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#         'location': -1}},
#       {'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'key'}}],
#           'location': 36}},
#         'sortby_dir': 'SORTBY_ASC',
#         'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#         'location': -1}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT * FROM foo LIMIT 10 OFFSET 20")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 14}}],
#      'limitOffset': {'A_Const': {'ival': {'ival': 20}, 'location': 34}},
#      'limitCount': {'A_Const': {'ival': {'ival': 10}, 'location': 24}},
#      'limitOption': 'LIMIT_OPTION_COUNT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT R.a, min(R.b) AS foo FROM R GROUP BY R.a ORDER BY R.a, foo")
json.loads(parse_tree)["stmts"][0]["stmt"]["SelectStmt"]
# Out:
# {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#        {'String': {'sval': 'a'}}],
#       'location': 7}},
#     'location': 7}},
#   {'ResTarget': {'name': 'foo',
#     'val': {'FuncCall': {'funcname': [{'String': {'sval': 'min'}}],
#       'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#           {'String': {'sval': 'b'}}],
#          'location': 16}}],
#       'funcformat': 'COERCE_EXPLICIT_CALL',
#       'location': 12}},
#     'location': 12}}],
#  'fromClause': [{'RangeVar': {'relname': 'r',
#     'inh': True,
#     'relpersistence': 'p',
#     'location': 33}}],
#  'groupClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#      {'String': {'sval': 'a'}}],
#     'location': 44}}],
#  'sortClause': [{'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'r'}},
#        {'String': {'sval': 'a'}}],
#       'location': 57}},
#     'sortby_dir': 'SORTBY_DEFAULT',
#     'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#     'location': -1}},
#   {'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'foo'}}],
#       'location': 62}},
#     'sortby_dir': 'SORTBY_DEFAULT',
#     'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#     'location': -1}}],
#  'limitOption': 'LIMIT_OPTION_DEFAULT',
#  'op': 'SETOP_NONE'}

# %% [markdown]
# ## Common Table Expressions

# %%
parse_tree = pglast.parser.parse_sql_json("""
WITH top100_posters AS (
	SELECT owner_user_id, COUNT(*) AS n_answers
	FROM answer, site
	WHERE site.site_name = 'stackoverflow'
		AND answer.site_id = site.site_id
	GROUP BY owner_user_id
	ORDER BY n_answers DESC
	LIMIT 100
)
SELECT account.display_name, top100_posters.n_answers
FROM account, so_user, site, top100_posters
WHERE site.site_name = 'stackoverflow'
	AND account.id = so_user.account_id
	AND site.site_id = so_user.site_id
	AND so_user.id = top100_posters.owner_user_id;
""")

# %%
parse_tree = pglast.parser.parse_sql_json("""
WITH t_a AS (SELECT 1),
    t_b AS (SELECT 2)
SELECT *
FROM R, t_a, t_b
""")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 54}},
#         'location': 54}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 61}},
#       {'RangeVar': {'relname': 't_a',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 64}},
#       {'RangeVar': {'relname': 't_b',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 69}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'withClause': {'ctes': [{'CommonTableExpr': {'ctename': 't_a',
#          'ctematerialized': 'CTEMaterializeDefault',
#          'ctequery': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 1},
#                 'location': 21}},
#               'location': 21}}],
#            'limitOption': 'LIMIT_OPTION_DEFAULT',
#            'op': 'SETOP_NONE'}},
#          'location': 6}},
#        {'CommonTableExpr': {'ctename': 't_b',
#          'ctematerialized': 'CTEMaterializeDefault',
#          'ctequery': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 2},
#                 'location': 44}},
#               'location': 44}}],
#            'limitOption': 'LIMIT_OPTION_DEFAULT',
#            'op': 'SETOP_NONE'}},
#          'location': 29}}],
#       'location': 1},
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Window functions

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT LAG(a) OVER () FROM R")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'lag'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'a'}}],
#              'location': 11}}],
#           'over': {'frameOptions': 1058, 'location': 19},
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 27}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT LAG(a) OVER () AS f FROM R")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'name': 'f',
#         'val': {'FuncCall': {'funcname': [{'String': {'sval': 'lag'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'a'}}],
#              'location': 11}}],
#           'over': {'frameOptions': 1058, 'location': 19},
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'relname': 'r',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 32}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT depname, empno, salary, avg(salary) OVER (PARTITION BY depname) FROM empsalary")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'depname'}}],
#           'location': 7}},
#         'location': 7}},
#       {'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'empno'}}],
#           'location': 16}},
#         'location': 16}},
#       {'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#           'location': 23}},
#         'location': 23}},
#       {'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'avg'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#              'location': 35}}],
#           'over': {'partitionClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'depname'}}],
#               'location': 62}}],
#            'frameOptions': 1058,
#            'location': 48},
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 31}},
#         'location': 31}}],
#      'fromClause': [{'RangeVar': {'relname': 'empsalary',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 76}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("""
SELECT depname, empno, salary,
    rank() OVER (PARTITION BY depname ORDER BY salary DESC)
FROM empsalary;
""")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'depname'}}],
#           'location': 8}},
#         'location': 8}},
#       {'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'empno'}}],
#           'location': 17}},
#         'location': 17}},
#       {'ResTarget': {'val': {'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#           'location': 24}},
#         'location': 24}},
#       {'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'rank'}}],
#           'over': {'partitionClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'depname'}}],
#               'location': 62}}],
#            'orderClause': [{'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#                 'location': 79}},
#               'sortby_dir': 'SORTBY_DESC',
#               'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#               'location': -1}}],
#            'frameOptions': 1058,
#            'location': 48},
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 36}},
#         'location': 36}}],
#      'fromClause': [{'RangeVar': {'relname': 'empsalary',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 97}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}},
#    'stmt_len': 106}]}

# %%
parse_tree = pglast.parser.parse_sql_json("""
SELECT SUM(salary) OVER (PARTITION BY depname, empno ORDER BY salary DESC, empno)
FROM empsalary;
""")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'sum'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#              'location': 12}}],
#           'over': {'partitionClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'depname'}}],
#               'location': 39}},
#             {'ColumnRef': {'fields': [{'String': {'sval': 'empno'}}],
#               'location': 48}}],
#            'orderClause': [{'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#                 'location': 63}},
#               'sortby_dir': 'SORTBY_DESC',
#               'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#               'location': -1}},
#             {'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'empno'}}],
#                 'location': 76}},
#               'sortby_dir': 'SORTBY_DEFAULT',
#               'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#               'location': -1}}],
#            'frameOptions': 1058,
#            'location': 25},
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 8}},
#         'location': 8}}],
#      'fromClause': [{'RangeVar': {'relname': 'empsalary',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 88}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}},
#    'stmt_len': 97}]}

# %%
parse_tree = pglast.parser.parse_sql_json("""
SELECT SUM(salary) FILTER (WHERE salary > 100) OVER (PARTITION BY depname, empno ORDER BY salary DESC, empno)
FROM empsalary;
""")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'FuncCall': {'funcname': [{'String': {'sval': 'sum'}}],
#           'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#              'location': 12}}],
#           'agg_filter': {'A_Expr': {'kind': 'AEXPR_OP',
#             'name': [{'String': {'sval': '>'}}],
#             'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#               'location': 34}},
#             'rexpr': {'A_Const': {'ival': {'ival': 100}, 'location': 43}},
#             'location': 41}},
#           'over': {'partitionClause': [{'ColumnRef': {'fields': [{'String': {'sval': 'depname'}}],
#               'location': 67}},
#             {'ColumnRef': {'fields': [{'String': {'sval': 'empno'}}],
#               'location': 76}}],
#            'orderClause': [{'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'salary'}}],
#                 'location': 91}},
#               'sortby_dir': 'SORTBY_DESC',
#               'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#               'location': -1}},
#             {'SortBy': {'node': {'ColumnRef': {'fields': [{'String': {'sval': 'empno'}}],
#                 'location': 104}},
#               'sortby_dir': 'SORTBY_DEFAULT',
#               'sortby_nulls': 'SORTBY_NULLS_DEFAULT',
#               'location': -1}}],
#            'frameOptions': 1058,
#            'location': 53},
#           'funcformat': 'COERCE_EXPLICIT_CALL',
#           'location': 8}},
#         'location': 8}}],
#      'fromClause': [{'RangeVar': {'relname': 'empsalary',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 116}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}},
#    'stmt_len': 125}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT 1")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 1},
#           'location': 7}},
#         'location': 7}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %% [markdown]
# ## Set operations

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT 1 UNION SELECT 2")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_UNION',
#      'larg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 1},
#            'location': 7}},
#          'location': 7}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'},
#      'rarg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 2},
#            'location': 22}},
#          'location': 22}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'}}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT 1 UNION ALL SELECT 2")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_UNION',
#      'all': True,
#      'larg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 1},
#            'location': 7}},
#          'location': 7}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'},
#      'rarg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 2},
#            'location': 26}},
#          'location': 26}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'}}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT 1 EXCEPT SELECT 2")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_EXCEPT',
#      'larg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 1},
#            'location': 7}},
#          'location': 7}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'},
#      'rarg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 2},
#            'location': 23}},
#          'location': 23}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'}}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT 1 INTERSECT SELECT 2")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_INTERSECT',
#      'larg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 1},
#            'location': 7}},
#          'location': 7}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'},
#      'rarg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 2},
#            'location': 26}},
#          'location': 26}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'}}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT 1 EXCEPT SELECT 2 UNION SELECT 3")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_UNION',
#      'larg': {'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_EXCEPT',
#       'larg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 1},
#             'location': 7}},
#           'location': 7}}],
#        'limitOption': 'LIMIT_OPTION_DEFAULT',
#        'op': 'SETOP_NONE'},
#       'rarg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 2},
#             'location': 23}},
#           'location': 23}}],
#        'limitOption': 'LIMIT_OPTION_DEFAULT',
#        'op': 'SETOP_NONE'}},
#      'rarg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 3},
#            'location': 38}},
#          'location': 38}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'}}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT 1 EXCEPT (SELECT 2 UNION SELECT 3)")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_EXCEPT',
#      'larg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 1},
#            'location': 7}},
#          'location': 7}}],
#       'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_NONE'},
#      'rarg': {'limitOption': 'LIMIT_OPTION_DEFAULT',
#       'op': 'SETOP_UNION',
#       'larg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 2},
#             'location': 24}},
#           'location': 24}}],
#        'limitOption': 'LIMIT_OPTION_DEFAULT',
#        'op': 'SETOP_NONE'},
#       'rarg': {'targetList': [{'ResTarget': {'val': {'A_Const': {'ival': {'ival': 3},
#             'location': 39}},
#           'location': 39}}],
#        'limitOption': 'LIMIT_OPTION_DEFAULT',
#        'op': 'SETOP_NONE'}}}}}]}

# %% [markdown]
# ## Array functions

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT ARRAY[1, 2, 3]")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_ArrayExpr': {'elements': [{'A_Const': {'ival': {'ival': 1},
#              'location': 13}},
#            {'A_Const': {'ival': {'ival': 2}, 'location': 16}},
#            {'A_Const': {'ival': {'ival': 3}, 'location': 19}}],
#           'location': 7}},
#         'location': 7}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT ARRAY[]::int[]")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'TypeCast': {'arg': {'A_ArrayExpr': {'location': 7}},
#           'typeName': {'names': [{'String': {'sval': 'pg_catalog'}},
#             {'String': {'sval': 'int4'}}],
#            'typemod': -1,
#            'arrayBounds': [{'Integer': {'ival': -1}}],
#            'location': 16},
#           'location': 14}},
#         'location': 7}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT ARRAY[1, 2, 3] @> ARRAY[2]")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '@>'}}],
#           'lexpr': {'A_ArrayExpr': {'elements': [{'A_Const': {'ival': {'ival': 1},
#                'location': 13}},
#              {'A_Const': {'ival': {'ival': 2}, 'location': 16}},
#              {'A_Const': {'ival': {'ival': 3}, 'location': 19}}],
#             'location': 7}},
#           'rexpr': {'A_ArrayExpr': {'elements': [{'A_Const': {'ival': {'ival': 2},
#                'location': 31}}],
#             'location': 25}},
#           'location': 22}},
#         'location': 7}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("SELECT ARRAY[1, 2, 3] && ARRAY[2]")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Expr': {'kind': 'AEXPR_OP',
#           'name': [{'String': {'sval': '&&'}}],
#           'lexpr': {'A_ArrayExpr': {'elements': [{'A_Const': {'ival': {'ival': 1},
#                'location': 13}},
#              {'A_Const': {'ival': {'ival': 2}, 'location': 16}},
#              {'A_Const': {'ival': {'ival': 3}, 'location': 19}}],
#             'location': 7}},
#           'rexpr': {'A_ArrayExpr': {'elements': [{'A_Const': {'ival': {'ival': 2},
#                'location': 31}}],
#             'location': 25}},
#           'location': 22}},
#         'location': 7}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}

# %%
parse_tree = pglast.parser.parse_sql_json("WITH foo AS (SELECT ARRAY[1,2,3] AS a) SELECT a[1] FROM foo")
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'A_Indirection': {'arg': {'ColumnRef': {'fields': [{'String': {'sval': 'a'}}],
#             'location': 46}},
#           'indirection': [{'A_Indices': {'uidx': {'A_Const': {'ival': {'ival': 1},
#                'location': 48}}}}]}},
#         'location': 46}}],
#      'fromClause': [{'RangeVar': {'relname': 'foo',
#         'inh': True,
#         'relpersistence': 'p',
#         'location': 56}}],
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'withClause': {'ctes': [{'CommonTableExpr': {'ctename': 'foo',
#          'ctematerialized': 'CTEMaterializeDefault',
#          'ctequery': {'SelectStmt': {'targetList': [{'ResTarget': {'name': 'a',
#               'val': {'A_ArrayExpr': {'elements': [{'A_Const': {'ival': {'ival': 1},
#                    'location': 26}},
#                  {'A_Const': {'ival': {'ival': 2}, 'location': 28}},
#                  {'A_Const': {'ival': {'ival': 3}, 'location': 30}}],
#                 'location': 20}},
#               'location': 20}}],
#            'limitOption': 'LIMIT_OPTION_DEFAULT',
#            'op': 'SETOP_NONE'}},
#          'location': 5}}]},
#      'op': 'SETOP_NONE'}}}]}

# %%
raw = """select * FROM
                            "b64877cf-78cd-4715-8395-0f12c93e9b34_1:everest:appserver_4v1"."EverestAssociation_1108v3" t
                        WHERE
                            TRUE
                            AND "_xid_start" <> ALL ((ARRAY[]::BIGINT[])::BIGINT[])
                            AND (
                                "valid_range" @> TIMESTAMPTZ '2025-11-18T09:58:12.480+00:00'
                                OR (
                                    LOWER("valid_range") <= '2025-11-18T09:58:12.480+00:00'
                                    AND "_xid_end" = ANY ((ARRAY[]::BIGINT[])::BIGINT[])
                                )
                            )"""

parse_tree = pglast.parser.parse_sql_json(raw)
json.loads(parse_tree)
# Out:
# {'version': 170004,
#  'stmts': [{'stmt': {'SelectStmt': {'targetList': [{'ResTarget': {'val': {'ColumnRef': {'fields': [{'A_Star': {}}],
#           'location': 7}},
#         'location': 7}}],
#      'fromClause': [{'RangeVar': {'schemaname': 'b64877cf-78cd-4715-8395-0f12c93e9b34_1:everest:appserver_4v1',
#         'relname': 'EverestAssociation_1108v3',
#         'inh': True,
#         'relpersistence': 'p',
#         'alias': {'aliasname': 't'},
#         'location': 42}}],
#      'whereClause': {'BoolExpr': {'boolop': 'AND_EXPR',
#        'args': [{'A_Const': {'boolval': {'boolval': True}, 'location': 193}},
#         {'A_Expr': {'kind': 'AEXPR_OP_ALL',
#           'name': [{'String': {'sval': '<>'}}],
#           'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': '_xid_start'}}],
#             'location': 230}},
#           'rexpr': {'TypeCast': {'arg': {'TypeCast': {'arg': {'A_ArrayExpr': {'location': 252}},
#               'typeName': {'names': [{'String': {'sval': 'pg_catalog'}},
#                 {'String': {'sval': 'int8'}}],
#                'typemod': -1,
#                'arrayBounds': [{'Integer': {'ival': -1}}],
#                'location': 261},
#               'location': 259}},
#             'typeName': {'names': [{'String': {'sval': 'pg_catalog'}},
#               {'String': {'sval': 'int8'}}],
#              'typemod': -1,
#              'arrayBounds': [{'Integer': {'ival': -1}}],
#              'location': 272},
#             'location': 270}},
#           'location': 243}},
#         {'BoolExpr': {'boolop': 'OR_EXPR',
#           'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#              'name': [{'String': {'sval': '@>'}}],
#              'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': 'valid_range'}}],
#                'location': 348}},
#              'rexpr': {'TypeCast': {'arg': {'A_Const': {'sval': {'sval': '2025-11-18T09:58:12.480+00:00'},
#                  'location': 377}},
#                'typeName': {'names': [{'String': {'sval': 'timestamptz'}}],
#                 'typemod': -1,
#                 'location': 365},
#                'location': -1}},
#              'location': 362}},
#            {'BoolExpr': {'boolop': 'AND_EXPR',
#              'args': [{'A_Expr': {'kind': 'AEXPR_OP',
#                 'name': [{'String': {'sval': '<='}}],
#                 'lexpr': {'FuncCall': {'funcname': [{'String': {'sval': 'lower'}}],
#                   'args': [{'ColumnRef': {'fields': [{'String': {'sval': 'valid_range'}}],
#                      'location': 488}}],
#                   'funcformat': 'COERCE_EXPLICIT_CALL',
#                   'location': 482}},
#                 'rexpr': {'A_Const': {'sval': {'sval': '2025-11-18T09:58:12.480+00:00'},
#                   'location': 506}},
#                 'location': 503}},
#               {'A_Expr': {'kind': 'AEXPR_OP_ANY',
#                 'name': [{'String': {'sval': '='}}],
#                 'lexpr': {'ColumnRef': {'fields': [{'String': {'sval': '_xid_end'}}],
#                   'location': 578}},
#                 'rexpr': {'TypeCast': {'arg': {'TypeCast': {'arg': {'A_ArrayExpr': {'location': 597}},
#                     'typeName': {'names': [{'String': {'sval': 'pg_catalog'}},
#                       {'String': {'sval': 'int8'}}],
#                      'typemod': -1,
#                      'arrayBounds': [{'Integer': {'ival': -1}}],
#                      'location': 606},
#                     'location': 604}},
#                   'typeName': {'names': [{'String': {'sval': 'pg_catalog'}},
#                     {'String': {'sval': 'int8'}}],
#                    'typemod': -1,
#                    'arrayBounds': [{'Integer': {'ival': -1}}],
#                    'location': 617},
#                   'location': 615}},
#                 'location': 589}}],
#              'location': 574}}],
#           'location': 441}}],
#        'location': 226}},
#      'limitOption': 'LIMIT_OPTION_DEFAULT',
#      'op': 'SETOP_NONE'}}}]}
