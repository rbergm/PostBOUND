# %% [markdown]
# # UES workload analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import re
import warnings

import numpy as np
import pandas as pd
import seaborn as sns

from transform import db, mosp
from postgres import explain

# %%
sns.set_theme(style="whitegrid")

# %%
df_raw = pd.read_csv("workloads/job-ues-results-fks-nonlj.csv")

# %%
df_raw.groupby(["run", "workload"])["rt_total"].sum()
# Out:
# run  workload
# 1    transformed    181.697190
#      ues            149.424562
# 2    transformed    180.440391
#      ues            149.746419
# 3    transformed    181.162909
#      ues            148.810540
# Name: rt_total, dtype: float64

# %% [markdown]
# Choose the fastest runs per setting as representatives.

# %%
repr_trans = df_raw.loc[(df_raw.workload == "transformed") & (df_raw.run == 2)]
repr_ues = df_raw.loc[(df_raw.workload == "ues") & (df_raw.run == 3)]
df = pd.concat([repr_ues, repr_trans])

# %%
def parse_query_plans(sample: pd.Series) -> explain.PlanNode:
    query, plan, workload = sample["query"], sample["result"], sample["workload"]
    if workload == "ues":
        parsed_plan = explain.parse_explain_analyze(query, plan)
    elif workload == "transformed":
        parsed_plan = explain.parse_explain_analyze(query, plan, with_subqueries=False)
    else:
        warnings.warn("Unknown workload '{}', assuming no subqueries".format(workload))
        parsed_plan = explain.parse_explain_analyze(query, plan, with_subqueries=False)
    return parsed_plan

# %%
df.result = df.result.apply(json.loads)
df["query"] = df["query"].apply(mosp.MospQuery.parse)
df["explain"] = df.result
df.result = df.apply(parse_query_plans, axis="columns")
df["subquery"] = df.result.apply(explain.PlanNode.extract_subqueries)
df = df.explode("subquery")
df
# Out:
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:336: UserWarning: Unknown node type: Aggregate
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:336: UserWarning: Unknown node type: Gather
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:336: UserWarning: Unknown node type: Hash
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:336: UserWarning: Unknown node type: Sort
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:336: UserWarning: Unknown node type: Materialize
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:336: UserWarning: Unknown node type: Gather Merge
#   warnings.warn("Unknown node type: {}".format(node_type))
#     label                                              query  \
# 226    1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 227    1b  SELECT COUNT(*) FROM movie_info_idx AS mi_idx ...
# 228    1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 229    1d  SELECT COUNT(*) FROM movie_info_idx AS mi_idx ...
# 230    2a  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# ..    ...                                                ...
# 560   32a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 561   32b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 562   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 563   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 564   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                                 result  rt_total  run  \
# 226  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...  0.439545    3
# 227  Hash Join (mc.company_type_id = ct.id) <- [Has...  0.325870    3
# 228  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...  0.348425    3
# 229  Hash Join (mc.company_type_id = ct.id) <- [Has...  0.328748    3
# 230  Hash Join (cn.id = mc.company_id) <- [Seq Scan...  0.848735    3
# ..                                                 ...       ...  ...
# 560  Hash Join (mk.keyword_id = k.id) <- [Merge Joi...  0.444229    2
# 561  Hash Join (mk.keyword_id = k.id) <- [Merge Joi...  0.432801    2
# 562  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...  1.064475    2
# 563  Hash Join (mc1.company_id = cn1.id) <- [Hash J...  1.292542    2
# 564  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...  1.189302    2
#
#         workload                                            explain  \
# 226          ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 227          ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 228          ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 229          ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 230          ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..           ...                                                ...
# 560  transformed  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 561  transformed  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 562  transformed  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 563  transformed  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 564  transformed  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery
# 226  Hash Join (mi_idx.info_type_id = it.id) <- [Se...
# 227                                                NaN
# 228  Hash Join (mi_idx.info_type_id = it.id) <- [Se...
# 229                                                NaN
# 230                                                NaN
# ..                                                 ...
# 560                                                NaN
# 561                                                NaN
# 562                                                NaN
# 563                                                NaN
# 564                                                NaN
#
# [259 rows x 8 columns]

# %%
df_ues = df[df.workload == "ues"].copy()
df_trans = df[df.workload == "transformed"].copy()

# %%
df_sqs = df_ues[~df_ues.subquery.isna()].copy()
df_sqs["pruned"] = df_sqs.subquery.apply(lambda sq: sq.any_pruned())
len(df_sqs)
# Out:
# 112

# %%
df_sqs
# Out:
#     label                                              query  \
# 226    1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 228    1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 232    2c  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 234    3a  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 235    3b  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..    ...                                                ...
# 336   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 337   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 337   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 338   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 338   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                                 result  rt_total  run  \
# 226  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...  0.439545    3
# 228  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...  0.348425    3
# 232  Hash Join (mc.movie_id = t.id) <- [Hash Join (...  0.561410    3
# 234  Hash Join (t.id = mk.movie_id) <- [Hash Join (...  1.539704    3
# 235  Hash Join (mk.movie_id = t.id) <- [~Hash Join~...  0.572723    3
# ..                                                 ...       ...  ...
# 336  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...  1.082079    3
# 337  Hash Join (mc1.company_id = cn1.id) <- [Hash J...  1.360770    3
# 337  Hash Join (mc1.company_id = cn1.id) <- [Hash J...  1.360770    3
# 338  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...  1.208609    3
# 338  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...  1.208609    3
#
#     workload                                            explain  \
# 226      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 228      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 232      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 234      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 235      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..       ...                                                ...
# 336      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 337      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 337      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 338      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 338      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery  pruned
# 226  Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 228  Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 232  Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 234  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# 235  ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# ..                                                 ...     ...
# 336  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 337  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 337  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 338  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 338  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
# [112 rows x 9 columns]

# %%
df_cmp = pd.merge(
    df_sqs.drop(columns=["run", "workload"]),
    df_trans.drop(columns=["run", "workload", "subquery"]),
    on="label", how="inner",
    suffixes=("_orig", "_trans"))
df_cmp["sq_pred"] = df_cmp.subquery.apply(getattr, args=("join_pred",))
df.rename(columns={"rt_total_orig": "rt_orig", "rt_total_trans": "rt_trans"}, inplace=True)
len(df_cmp)
# Out:
# 112

# %%
df_cmp
# Out:
#     label                                         query_orig  \
# 0      1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1      1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2      2c  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3      3a  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4      3b  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..    ...                                                ...
# 107   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                            result_orig  rt_total_orig  \
# 0    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...       0.439545
# 1    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...       0.348425
# 2    Hash Join (mc.movie_id = t.id) <- [Hash Join (...       0.561410
# 3    Hash Join (t.id = mk.movie_id) <- [Hash Join (...       1.539704
# 4    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...       0.572723
# ..                                                 ...            ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...       1.082079
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...       1.360770
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...       1.360770
# 110  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...       1.208609
# 111  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...       1.208609
#
#                                           explain_orig  \
# 0    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                 ...
# 107  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 108  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 109  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 110  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 111  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery  pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 3    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# 4    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# ..                                                 ...     ...
# 107  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 108  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 109  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
#                                            query_trans  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..                                                 ...
# 107  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                           result_trans  rt_total_trans  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...        0.459900
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...        0.448824
# 2    Hash Join (mc.company_id = cn.id) <- [Hash Joi...        0.587651
# 3    Hash Join (mk.keyword_id = k.id) <- [Hash Join...        1.292148
# 4    Hash Join (mk.keyword_id = k.id) <- [Hash Join...        0.591094
# ..                                                 ...             ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...        1.064475
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...        1.292542
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...        1.292542
# 110  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...        1.189302
# 111  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...        1.189302
#
#                                          explain_trans  \
# 0    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                 ...
# 107  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 108  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 109  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 110  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 111  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                              sq_pred
# 0      (mi_idx.info_type_id = it.id)
# 1      (mi_idx.info_type_id = it.id)
# 2            (mc.company_id = cn.id)
# 3             (mk.keyword_id = k.id)
# 4             (mk.keyword_id = k.id)
# ..                               ...
# 107  (mi_idx1.info_type_id = it1.id)
# 108  (mi_idx2.info_type_id = it2.id)
# 109  (mi_idx1.info_type_id = it1.id)
# 110  (mi_idx2.info_type_id = it2.id)
# 111  (mi_idx1.info_type_id = it1.id)
#
# [112 rows x 12 columns]

# %%
def subquery_join_partner(subquery):
    parent = subquery.parent
    left, right = parent.left, parent.right
    partner = left if subquery.join_pred == right.join_pred else right
    return partner

# %%
df_cmp["sq_fk_partner"] = df_cmp.apply(lambda row: row["result_orig"].lookup_subquery(row["sq_pred"]), axis="columns").apply(lambda sq: sq.base_table())
df_cmp["sq_fk_table"] = df_cmp.apply(lambda row: row["result_orig"].lookup_scan(row["sq_fk_partner"]), axis="columns")
df_cmp["sq_fk_rows"] = df_cmp["sq_fk_table"].apply(lambda tab: tab.proc_rows)

df_cmp["sq_join"] = df_cmp.apply(lambda row: row["result_orig"].lookup_join(row["sq_pred"]), axis="columns")
df_cmp["sq_join_rows"] = df_cmp["sq_join"].apply(lambda join: join.proc_rows)
df_cmp["sq_join_duration"] = df_cmp["sq_join"].apply(lambda join: join.exec_time[0] / 1000)

df_cmp["sq_join_partner"] = df_cmp["sq_join"].apply(subquery_join_partner)
df_cmp["sq_join_partner_duration"] = df_cmp["sq_join_partner"].apply(lambda join: join.exec_time[0] / 1000)

df_cmp["node_pruned_orig"] = df_cmp.result_orig.apply(lambda plan: plan.any_pruned(exclude_subqueries=True))
df_cmp["node_pruned_trans"] = df_cmp.result_trans.apply(lambda plan: plan.any_pruned(exclude_subqueries=True))

# %%
df_cmp
# Out:
#     label                                         query_orig  \
# 0      1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1      1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2      2c  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3      3a  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4      3b  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..    ...                                                ...
# 107   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                            result_orig  rt_total_orig  \
# 0    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...       0.439545
# 1    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...       0.348425
# 2    Hash Join (mc.movie_id = t.id) <- [Hash Join (...       0.561410
# 3    Hash Join (t.id = mk.movie_id) <- [Hash Join (...       1.539704
# 4    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...       0.572723
# ..                                                 ...            ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...       1.082079
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...       1.360770
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...       1.360770
# 110  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...       1.208609
# 111  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...       1.208609
#
#                                           explain_orig  \
# 0    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                 ...
# 107  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 108  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 109  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 110  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 111  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery  pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 3    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# 4    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# ..                                                 ...     ...
# 107  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 108  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 109  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
#                                            query_trans  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..                                                 ...
# 107  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                           result_trans  rt_total_trans  ...  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...        0.459900  ...
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...        0.448824  ...
# 2    Hash Join (mc.company_id = cn.id) <- [Hash Joi...        0.587651  ...
# 3    Hash Join (mk.keyword_id = k.id) <- [Hash Join...        1.292148  ...
# 4    Hash Join (mk.keyword_id = k.id) <- [Hash Join...        0.591094  ...
# ..                                                 ...             ...  ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...        1.064475  ...
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...        1.292542  ...
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...        1.292542  ...
# 110  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...        1.189302  ...
# 111  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...        1.189302  ...
#
#                  sq_fk_partner                  sq_fk_table sq_fk_rows  \
# 0     movie_info_idx AS mi_idx   Seq Scan :: movie_info_idx     460012
# 1     movie_info_idx AS mi_idx   Seq Scan :: movie_info_idx     460012
# 2        movie_companies AS mc  Seq Scan :: movie_companies     869710
# 3          movie_keyword AS mk    Seq Scan :: movie_keyword    1507977
# 4          movie_keyword AS mk  ~Seq Scan~ :: movie_keyword          0
# ..                         ...                          ...        ...
# 107  movie_info_idx AS mi_idx1   Seq Scan :: movie_info_idx     690018
# 108  movie_info_idx AS mi_idx2   Seq Scan :: movie_info_idx     654961
# 109  movie_info_idx AS mi_idx1   Seq Scan :: movie_info_idx    1380035
# 110  movie_info_idx AS mi_idx2   Seq Scan :: movie_info_idx     351960
# 111  movie_info_idx AS mi_idx1   Seq Scan :: movie_info_idx     690018
#
#                                                sq_join  sq_join_rows  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            83
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            83
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...             1
# 3    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...          4317
# 4    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...             0
# ..                                                 ...           ...
# 107  Hash Join (mi_idx1.info_type_id = it1.id) <- [...        229962
# 108  Hash Join (mi_idx2.info_type_id = it2.id) <- [...         25591
# 109  Hash Join (mi_idx1.info_type_id = it1.id) <- [...        459925
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...         18374
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...        229962
#
#     sq_join_duration                                    sq_join_partner  \
# 0           0.064083  Hash Join (t.id = mc.movie_id) <- [Seq Scan ::...
# 1           0.063187  Hash Join (t.id = mc.movie_id) <- [Seq Scan ::...
# 2           0.131000  Hash Join (t.id = mk.movie_id) <- [Seq Scan ::...
# 3           0.220146  Hash Join (mi.movie_id = t.id) <- [Seq Scan ::...
# 4           0.000000  Hash Join (mi.movie_id = t.id) <- [Seq Scan ::...
# ..               ...                                                ...
# 107         0.115141  Hash Join (t2.kind_id = kt2.id) <- [Hash Join ...
# 108         0.221860  Hash Join (mi_idx1.movie_id = t1.id) <- [Hash ...
# 109         0.217341  Hash Join (t2.kind_id = kt2.id) <- [Hash Join ...
# 110         0.121368  Hash Join (mi_idx1.movie_id = t1.id) <- [Hash ...
# 111         0.114501  Hash Join (t2.kind_id = kt2.id) <- [Hash Join ...
#
#      sq_join_partner_duration node_pruned_orig  node_pruned_trans
# 0                    0.356114            False              False
# 1                    0.243332            False              False
# 2                    0.400316            False              False
# 3                    1.260173            False               True
# 4                    0.566448             True               True
# ..                        ...              ...                ...
# 107                  0.445078            False              False
# 108                  0.444502            False              False
# 109                  0.197167            False              False
# 110                  0.695499            False              False
# 111                  0.564965            False              False
#
# [112 rows x 22 columns]

# %%
df_cmp["filter_strength"] = df_cmp.sq_fk_rows / df_cmp.sq_join_rows
df_cmp["sq_speedup"] = df_cmp.rt_total_trans / df_cmp.rt_total_orig
df_cmp[["label", "subquery", "sq_fk_rows", "sq_join_rows", "rt_total_orig", "rt_total_trans", "filter_strength", "sq_speedup"]]
# Out:
#     label                                           subquery  sq_fk_rows  \
# 0      1a  Hash Join (mi_idx.info_type_id = it.id) <- [Se...      460012
# 1      1c  Hash Join (mi_idx.info_type_id = it.id) <- [Se...      460012
# 2      2c  Hash Join (mc.company_id = cn.id) <- [Seq Scan...      869710
# 3      3a  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...     1507977
# 4      3b  ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...           0
# ..    ...                                                ...         ...
# 107   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...      690018
# 108   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...      654961
# 109   33b  Hash Join (mi_idx1.info_type_id = it1.id) <- [...     1380035
# 110   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...      351960
# 111   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...      690018
#
#      sq_join_rows  rt_total_orig  rt_total_trans  filter_strength  sq_speedup
# 0              83       0.439545        0.459900      5542.313253    1.046309
# 1              83       0.348425        0.448824      5542.313253    1.288151
# 2               1       0.561410        0.587651    869710.000000    1.046741
# 3            4317       1.539704        1.292148       349.311327    0.839218
# 4               0       0.572723        0.591094              NaN    1.032077
# ..            ...            ...             ...              ...         ...
# 107        229962       1.082079        1.064475         3.000574    0.983731
# 108         25591       1.360770        1.292542        25.593412    0.949861
# 109        459925       1.360770        1.292542         3.000565    0.949861
# 110         18374       1.208609        1.189302        19.155328    0.984025
# 111        229962       1.208609        1.189302         3.000574    0.984025
#
# [112 rows x 8 columns]

# %%
df_export = df_cmp.drop(
    columns=["result_trans",
             "sq_pred",
             "sq_fk_partner",
             "sq_fk_table",
             "sq_join",
             "sq_join_partner",
             "explain_trans"
            ]).rename(
    columns={"result_orig": "ues_plan",
             "explain_orig": "ues_explain",
             "sq_fk_rows": "foreign_key_rows",
             "sq_join_rows": "rows_after_join",
             "rt_total_orig": "runtime_ues",
             "rt_total_trans": "runtime_flat",
             "sq_speedup": "ues_speedup",
             "query_orig": "query_ues",
             "query_trans": "query_flat",
             "sq_join_duration": "subquery_runtime",
             "sq_join_partner_duration": "subquery_partner_runtime",
             "pruned": "subquery_pruned",
             "node_pruned_orig": "ues_pruned",
             "node_pruned_trans": "flat_pruned"
            })
df_export["tables"] = df_export.query_ues.apply(lambda q: json.dumps([tab.full_name for tab in q.collect_tables()]))
df_export["subquery_tables"] = df_export.subquery.apply(lambda sq: sq.lookup_subquery(sq.join_pred).collect_tables()).apply(lambda sq_tabs: json.dumps([tab.full_name for tab in sq_tabs]))

df_export.ues_explain = df_export.ues_explain.apply(json.dumps)

df_export.to_csv("workloads/job-ues-eval-fks-nonlj.csv", index=False)
df_export
# Out:
#     label                                          query_ues  \
# 0      1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1      1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2      2c  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3      3a  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4      3b  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..    ...                                                ...
# 107   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                               ues_plan  runtime_ues  \
# 0    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...     0.439545
# 1    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...     0.348425
# 2    Hash Join (mc.movie_id = t.id) <- [Hash Join (...     0.561410
# 3    Hash Join (t.id = mk.movie_id) <- [Hash Join (...     1.539704
# 4    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...     0.572723
# ..                                                 ...          ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.082079
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...     1.360770
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...     1.360770
# 110  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.208609
# 111  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.208609
#
#                                            ues_explain  \
# 0    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 1    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 2    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 3    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 4    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# ..                                                 ...
# 107  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 108  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 109  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 110  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 111  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                               subquery  subquery_pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...            False
# 3    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...            False
# 4    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...             True
# ..                                                 ...              ...
# 107  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
# 108  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 109  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
#
#                                             query_flat  runtime_flat  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...      0.459900
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...      0.448824
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...      0.587651
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...      1.292148
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...      0.591094
# ..                                                 ...           ...
# 107  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.064475
# 108  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.292542
# 109  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.292542
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.189302
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.189302
#
#      foreign_key_rows  rows_after_join  subquery_runtime  \
# 0              460012               83          0.064083
# 1              460012               83          0.063187
# 2              869710                1          0.131000
# 3             1507977             4317          0.220146
# 4                   0                0          0.000000
# ..                ...              ...               ...
# 107            690018           229962          0.115141
# 108            654961            25591          0.221860
# 109           1380035           459925          0.217341
# 110            351960            18374          0.121368
# 111            690018           229962          0.114501
#
#      subquery_partner_runtime  ues_pruned  flat_pruned  filter_strength  \
# 0                    0.356114       False        False      5542.313253
# 1                    0.243332       False        False      5542.313253
# 2                    0.400316       False        False    869710.000000
# 3                    1.260173       False         True       349.311327
# 4                    0.566448        True         True              NaN
# ..                        ...         ...          ...              ...
# 107                  0.445078       False        False         3.000574
# 108                  0.444502       False        False        25.593412
# 109                  0.197167       False        False         3.000565
# 110                  0.695499       False        False        19.155328
# 111                  0.564965       False        False         3.000574
#
#      ues_speedup                                             tables  \
# 0       1.046309  ["movie_companies", "company_type", "title", "...
# 1       1.288151  ["movie_companies", "company_type", "title", "...
# 2       1.046741  ["movie_keyword", "keyword", "title", "movie_c...
# 3       0.839218  ["movie_info", "title", "movie_keyword", "keyw...
# 4       1.032077  ["movie_info", "title", "movie_keyword", "keyw...
# ..           ...                                                ...
# 107     0.983731  ["movie_link", "link_type", "title", "title", ...
# 108     0.949861  ["movie_link", "link_type", "title", "title", ...
# 109     0.949861  ["movie_link", "link_type", "title", "title", ...
# 110     0.984025  ["movie_link", "link_type", "title", "title", ...
# 111     0.984025  ["movie_link", "link_type", "title", "title", ...
#
#                          subquery_tables
# 0        ["movie_info_idx", "info_type"]
# 1        ["movie_info_idx", "info_type"]
# 2    ["movie_companies", "company_name"]
# 3           ["movie_keyword", "keyword"]
# 4           ["movie_keyword", "keyword"]
# ..                                   ...
# 107      ["movie_info_idx", "info_type"]
# 108      ["movie_info_idx", "info_type"]
# 109      ["movie_info_idx", "info_type"]
# 110      ["movie_info_idx", "info_type"]
# 111      ["movie_info_idx", "info_type"]
#
# [112 rows x 19 columns]

# %% [markdown]
# ## Some sanity checks for the export data set

# %%
df_export.groupby("label")[["label"]].count().rename(columns={"label": "count"}).reset_index().sort_values(by="count", ascending=False)
# Out:
#    label  count
# 58   31c      3
# 56   31a      3
# 39   25c      2
# 61   33a      2
# 57   31b      2
# ..   ...    ...
# 35   23c      1
# 36   24b      1
# 38   25b      1
# 40   26a      1
# 78    8d      1
#
# [79 rows x 2 columns]

# %%
df_export.loc[df_export.filter_strength.isna() & ~df_export.subquery_pruned]
# Out:
# Empty DataFrame
# Columns: [label, query_ues, ues_plan, runtime_ues, ues_explain, subquery, subquery_pruned, query_flat, runtime_flat, foreign_key_rows, rows_after_join, subquery_runtime, subquery_partner_runtime, ues_pruned, flat_pruned, filter_strength, ues_speedup, tables, subquery_tables]
# Index: []

# %%
df_export.loc[df_export.label == "6b"]
# Out:
#    label                                          query_ues  \
# 10    6b  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
#
#                                              ues_plan  runtime_ues  \
# 10  Hash Join (ci.movie_id = t.id) <- [Hash Join (...     0.536543
#
#                                           ues_explain  \
# 10  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                              subquery  subquery_pruned  \
# 10  Hash Join (ci.person_id = n.id) <- [~Seq Scan~...             True
#
#                                            query_flat  runtime_flat  \
# 10  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...      2.252002
#
#     foreign_key_rows  rows_after_join  subquery_runtime  \
# 10                 0                0          0.181875
#
#     subquery_partner_runtime  ues_pruned  flat_pruned  filter_strength  \
# 10                  0.349454        True        False              NaN
#
#     ues_speedup                                             tables  \
# 10     4.197244  ["movie_keyword", "keyword", "title", "cast_in...
#
#           subquery_tables
# 10  ["cast_info", "name"]

# %%
df_export.loc[df_export.label == "20b"].iloc[0].query_ues
# Out:
# SELECT COUNT(*) FROM complete_cast AS cc JOIN comp_cast_type AS cct1 ON cct1.kind = 'cast' AND cct1.id = cc.subject_id JOIN comp_cast_type AS cct2 ON cct2.kind LIKE '%complete%' AND cct2.id = cc.status_id JOIN title AS t ON t.production_year > 2000 AND t.id = cc.movie_id JOIN kind_type AS kt ON kt.kind = 'movie' AND kt.id = t.kind_id JOIN (SELECT movie_id FROM movie_keyword AS mk JOIN keyword AS k ON k.keyword IN ('superhero', 'sequel', 'second-part', 'marvel-comics', 'based-on-comic', 'tv-special', 'fight', 'violence') AND k.id = mk.keyword_id) AS t_mk ON t_mk.movie_id = cc.movie_id JOIN (SELECT person_id, movie_id FROM cast_info AS ci JOIN name AS n ON n.name LIKE '%downey%robert%' AND n.id = ci.person_id JOIN char_name AS chn ON chn.name NOT LIKE '%sherlock%' AND (chn.name LIKE '%tony%stark%' OR chn.name LIKE '%iron%man%') AND chn.id = ci.person_role_id) AS t_ci ON t_ci.movie_id = t_mk.movie_id

# %%
print(df_export.loc[df_export.label == "6b"].iloc[0].ues_plan.pretty_print(include_filter=True))
# Out:
# Hash Join (ci.movie_id = t.id)
#   <- [SQ] Hash Join (ci.person_id = n.id)
#     <- [PRUNED] Seq Scan :: cast_info
#     <- Seq Scan :: name (((name)::text ~~ '%downey%robert%'::text))
#   <- Hash Join (t.id = mk.movie_id)
#     <- Seq Scan :: title ((production_year > 2014))
#     <- Hash Join (mk.keyword_id = k.id)
#       <- Seq Scan :: movie_keyword
#       <- Seq Scan :: keyword (((keyword)::text = ANY ('{superhero,sequel,second-part,marvel-comics,based-on-comic,tv-special,fight,violence}'::text[])))

# %%
df_export.loc[df_export.label == "6b"].iloc[0].ues_explain
# Out:
# '[{"Plan": {"Node Type": "Aggregate", "Strategy": "Plain", "Partial Mode": "Simple", "Parallel Aware": false, "Async Capable": false, "Startup Cost": 622730.99, "Total Cost": 622731.0, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 534.419, "Actual Total Time": 535.652, "Actual Rows": 1, "Actual Loops": 1, "Plans": [{"Node Type": "Gather", "Parent Relationship": "Outer", "Parallel Aware": false, "Async Capable": false, "Startup Cost": 179377.81, "Total Cost": 622730.98, "Plan Rows": 1, "Plan Width": 0, "Actual Startup Time": 534.414, "Actual Total Time": 535.647, "Actual Rows": 0, "Actual Loops": 1, "Workers Planned": 2, "Workers Launched": 2, "Single Copy": false, "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 178377.81, "Total Cost": 621730.88, "Plan Rows": 1, "Plan Width": 0, "Actual Startup Time": 531.817, "Actual Total Time": 531.823, "Actual Rows": 0, "Actual Loops": 3, "Inner Unique": false, "Hash Cond": "(ci.movie_id = t.id)", "Workers": [], "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 77320.47, "Total Cost": 520667.86, "Plan Rows": 1511, "Plan Width": 4, "Actual Startup Time": 181.873, "Actual Total Time": 181.875, "Actual Rows": 0, "Actual Loops": 3, "Inner Unique": true, "Hash Cond": "(ci.person_id = n.id)", "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "cast_info", "Alias": "ci", "Startup Cost": 0.0, "Total Cost": 403705.1, "Plan Rows": 15101810, "Plan Width": 8, "Actual Startup Time": 0.0, "Actual Total Time": 0.0, "Actual Rows": 0, "Actual Loops": 0, "Workers": []}, {"Node Type": "Hash", "Parent Relationship": "Inner", "Parallel Aware": true, "Async Capable": false, "Startup Cost": 77318.29, "Total Cost": 77318.29, "Plan Rows": 174, "Plan Width": 4, "Actual Startup Time": 181.862, "Actual Total Time": 181.863, "Actual Rows": 0, "Actual Loops": 3, "Hash Buckets": 1024, "Original Hash Buckets": 1024, "Hash Batches": 1, "Original Hash Batches": 1, "Peak Memory Usage": 0, "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "name", "Alias": "n", "Startup Cost": 0.0, "Total Cost": 77318.29, "Plan Rows": 174, "Plan Width": 4, "Actual Startup Time": 181.83, "Actual Total Time": 181.83, "Actual Rows": 0, "Actual Loops": 3, "Filter": "((name)::text ~~ \'%downey%robert%\'::text)", "Rows Removed by Filter": 1389164, "Workers": []}]}]}, {"Node Type": "Hash", "Parent Relationship": "Inner", "Parallel Aware": true, "Async Capable": false, "Startup Cost": 101057.33, "Total Cost": 101057.33, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 349.542, "Actual Total Time": 349.546, "Actual Rows": 12, "Actual Loops": 3, "Hash Buckets": 1024, "Original Hash Buckets": 1024, "Hash Batches": 1, "Original Hash Batches": 1, "Peak Memory Usage": 104, "Workers": [], "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 51885.81, "Total Cost": 101057.33, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 274.84, "Actual Total Time": 349.454, "Actual Rows": 12, "Actual Loops": 3, "Inner Unique": false, "Hash Cond": "(t.id = mk.movie_id)", "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "title", "Alias": "t", "Startup Cost": 0.0, "Total Cost": 49166.29, "Plan Rows": 835, "Plan Width": 4, "Actual Startup Time": 0.272, "Actual Total Time": 77.493, "Actual Rows": 146, "Actual Loops": 3, "Filter": "(production_year > 2014)", "Rows Removed by Filter": 842625, "Workers": []}, {"Node Type": "Hash", "Parent Relationship": "Inne ...

# %%
df_export.loc[df_export.label == "33c"]
# Out:
#     label                                          query_ues  \
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                               ues_plan  runtime_ues  \
# 110  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.208609
# 111  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.208609
#
#                                            ues_explain  \
# 110  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 111  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                               subquery  subquery_pruned  \
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
#
#                                             query_flat  runtime_flat  \
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.189302
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.189302
#
#      foreign_key_rows  rows_after_join  subquery_runtime  \
# 110            351960            18374          0.121368
# 111            690018           229962          0.114501
#
#      subquery_partner_runtime  ues_pruned  flat_pruned  filter_strength  \
# 110                  0.695499       False        False        19.155328
# 111                  0.564965       False        False         3.000574
#
#      ues_speedup                                             tables  \
# 110     0.984025  ["movie_link", "link_type", "title", "title", ...
# 111     0.984025  ["movie_link", "link_type", "title", "title", ...
#
#                      subquery_tables
# 110  ["movie_info_idx", "info_type"]
# 111  ["movie_info_idx", "info_type"]

# %%
df_export.loc[df_export.label == "33c"].iloc[0].query_ues
# Out:
# SELECT COUNT(*) FROM movie_link AS ml JOIN link_type AS lt ON lt.link IN ('sequel', 'follows', 'followed by') AND lt.id = ml.link_type_id JOIN title AS t2 ON t2.production_year BETWEEN 2000 AND 2010 AND t2.id = ml.linked_movie_id JOIN title AS t1 ON t1.id = ml.movie_id JOIN kind_type AS kt1 ON kt1.kind IN ('tv series', 'episode') AND kt1.id = t1.kind_id JOIN kind_type AS kt2 ON kt2.kind IN ('tv series', 'episode') AND kt2.id = t2.kind_id JOIN (SELECT movie_id FROM movie_info_idx AS mi_idx1 JOIN info_type AS it1 ON it1.info = 'rating' AND it1.id = mi_idx1.info_type_id) AS t_mi_idx1 ON t_mi_idx1.movie_id = ml.movie_id JOIN (SELECT movie_id FROM movie_info_idx AS mi_idx2 JOIN info_type AS it2 ON it2.info = 'rating' AND it2.id = mi_idx2.info_type_id AND mi_idx2.info < '3.5') AS t_mi_idx2 ON t_mi_idx2.movie_id = ml.linked_movie_id JOIN movie_companies AS mc2 ON mc2.movie_id = ml.linked_movie_id JOIN company_name AS cn2 ON cn2.id = mc2.company_id JOIN movie_companies AS mc1 ON mc1.movie_id = ml.movie_id JOIN company_name AS cn1 ON cn1.country_code <> '[us]' AND cn1.id = mc1.company_id

# %%
print(df_export.loc[df_export.label == "33c"].iloc[0].ues_plan.pretty_print(include_filter=True))
# Out:
# Hash Join (cn1.id = mc1.company_id)
#   <- Seq Scan :: company_name (((country_code)::text <> '[us]'::text))
#   <- Hash Join (mc1.movie_id = t1.id)
#     <- Seq Scan :: movie_companies
#     <- Hash Join (cn2.id = mc2.company_id)
#       <- Seq Scan :: company_name
#       <- Hash Join (mc2.movie_id = t2.id)
#         <- Seq Scan :: movie_companies
#         <- Hash Join (mi_idx2.movie_id = t2.id)
#           <- [SQ] Hash Join (mi_idx2.info_type_id = it2.id)
#             <- Seq Scan :: movie_info_idx (((info)::text < '3.5'::text))
#             <- Seq Scan :: info_type (((info)::text = 'rating'::text))
#           <- Hash Join (mi_idx1.movie_id = t1.id)
#             <- [SQ] Hash Join (mi_idx1.info_type_id = it1.id)
#               <- Seq Scan :: movie_info_idx
#               <- Seq Scan :: info_type (((info)::text = 'rating'::text))
#             <- Hash Join (t2.kind_id = kt2.id)
#               <- Hash Join (t1.kind_id = kt1.id)
#                 <- Merge Join (t1.id = ml.movie_id)
#                   <- Index Scan :: title
#                   <- Hash Join (ml.linked_movie_id = t2.id)
#                     <- Hash Join (ml.link_type_id = lt.id)
#                       <- Seq Scan :: movie_link
#                       <- Seq Scan :: link_type (((link)::text = ANY ('{sequel,follows,"followed by"}'::text[])))
#                     <- Seq Scan :: title (((production_year >= 2000) AND (production_year <= 2010)))
#                 <- Seq Scan :: kind_type (((kind)::text = ANY ('{"tv series",episode}'::text[])))
#               <- Seq Scan :: kind_type (((kind)::text = ANY ('{"tv series",episode}'::text[])))
