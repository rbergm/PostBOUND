# %% [markdown]
# # UES workload analysis

# %% [markdown]
# ## Data loading

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import re
import warnings

import numpy as np
import pandas as pd
import seaborn as sns

from transform import db, mosp
from postgres import explain

# %%
sns.set_theme(style="whitegrid")

# %%
df_raw = pd.read_csv("workloads/job-ues-results-linearization.csv")

# %%
df_raw
# Out:
#      label                                              query  \
# 0       1a  select count(*) from  movie_companies as mc  j...
# 1       1b  select count(*) from  movie_info_idx as mi_idx...
# 2       1c  select count(*) from  movie_companies as mc  j...
# 3       1d  select count(*) from  movie_info_idx as mi_idx...
# 4       2a  select count(*) from  movie_keyword as mk  joi...
# ...    ...                                                ...
# 1125   32a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 1126   32b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 1127   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 1128   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 1129   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                            query_result  rt_total  run  \
# 0     [{"Plan": {"Node Type": "Aggregate", "Strategy...  3.028541    1
# 1     [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.571985    1
# 2     [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.672483    1
# 3     [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.609533    1
# 4     [{"Plan": {"Node Type": "Aggregate", "Strategy...  2.158585    1
# ...                                                 ...       ...  ...
# 1125  [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.010962    5
# 1126  [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.444687    5
# 1127  [{"Plan": {"Node Type": "Aggregate", "Strategy...  1.593583    5
# 1128  [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.683118    5
# 1129  [{"Plan": {"Node Type": "Aggregate", "Strategy...  1.809555    5
#
#             workload
# 0                ues
# 1                ues
# 2                ues
# 3                ues
# 4                ues
# ...              ...
# 1125  ues_linearized
# 1126  ues_linearized
# 1127  ues_linearized
# 1128  ues_linearized
# 1129  ues_linearized
#
# [1130 rows x 6 columns]

# %% [markdown]
# ## Initial analysis

# %% [markdown]
# Get a rough overview of the workload performance:

# %%
wrkld_run_grp = df_raw.groupby(["workload", "run",])["rt_total"].sum()
wrkld_run_grp
# Out:
# workload        run
# ues             1      287.526762
#                 2      270.411454
#                 3      271.353861
#                 4      265.445545
#                 5      267.553320
# ues_linearized  1      332.505916
#                 2      314.632555
#                 3      313.981810
#                 4      313.843529
#                 5      314.405119
# Name: rt_total, dtype: float64

# %% [markdown]
# The best runs per workload:

# %%
min_runs = wrkld_run_grp.loc[wrkld_run_grp.groupby("workload").idxmin()]
min_runs
# Out:
# workload        run
# ues             4      265.445545
# ues_linearized  4      313.843529
# Name: rt_total, dtype: float64

# %% [markdown]
# Choose the fastest runs per setting as representatives.

# %%
# first up, perform a full inner join on workload and run. This way, we can obtain all rows that are part of the best runs per workload
df_wrkld_run_idx = df_raw.merge(min_runs, how="inner", left_on=["workload", "run"], right_on=["workload", "run"], right_index=True).index

# secondly, use the index to extract the rows only, without superfluous colunms
df = df_raw.loc[df_wrkld_run_idx].reset_index(drop=True).copy()
df
# Out:
#     label                                              query  \
# 0      1a  select count(*) from  movie_companies as mc  j...
# 1      1b  select count(*) from  movie_info_idx as mi_idx...
# 2      1c  select count(*) from  movie_companies as mc  j...
# 3      1d  select count(*) from  movie_info_idx as mi_idx...
# 4      2a  select count(*) from  movie_keyword as mk  joi...
# ..    ...                                                ...
# 221   32a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 222   32b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 223   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 224   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 225   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                           query_result  rt_total  run  \
# 0    [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.792273    4
# 1    [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.553238    4
# 2    [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.636802    4
# 3    [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.619424    4
# 4    [{"Plan": {"Node Type": "Aggregate", "Strategy...  1.095501    4
# ..                                                 ...       ...  ...
# 221  [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.010631    4
# 222  [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.441383    4
# 223  [{"Plan": {"Node Type": "Aggregate", "Strategy...  1.510462    4
# 224  [{"Plan": {"Node Type": "Aggregate", "Strategy...  0.688176    4
# 225  [{"Plan": {"Node Type": "Aggregate", "Strategy...  1.813502    4
#
#            workload
# 0               ues
# 1               ues
# 2               ues
# 3               ues
# 4               ues
# ..              ...
# 221  ues_linearized
# 222  ues_linearized
# 223  ues_linearized
# 224  ues_linearized
# 225  ues_linearized
#
# [226 rows x 6 columns]

# %% [markdown]
# ## Feature calculation

# %%
def parse_query_plans(sample: pd.Series) -> explain.PlanNode:
    query, plan, workload = sample["query"], sample["query_result"], sample["workload"]
    if workload == "ues":
        parsed_plan = explain.parse_explain_analyze(query, plan)
    elif workload == "ues_linearized":
        parsed_plan = explain.parse_explain_analyze(query, plan, with_subqueries=False)
    else:
        warnings.warn("Unknown workload '{}', assuming no subqueries".format(workload))
        parsed_plan = explain.parse_explain_analyze(query, plan, with_subqueries=False)
    return parsed_plan

# %%
df.query_result = df.query_result.apply(json.loads)
df["query"] = df["query"].apply(mosp.MospQuery.parse)
df["explain"] = df.query_result
df.query_result = df.apply(parse_query_plans, axis="columns")
df["subquery"] = df.query_result.apply(explain.PlanNode.extract_subqueries)
df = df.explode("subquery")
df
# Out:
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:335: UserWarning: Unknown node type: Aggregate
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:335: UserWarning: Unknown node type: Gather
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:335: UserWarning: Unknown node type: Hash
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:335: UserWarning: Unknown node type: Sort
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:335: UserWarning: Unknown node type: Gather Merge
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:335: UserWarning: Unknown node type: Materialize
#   warnings.warn("Unknown node type: {}".format(node_type))
#     label                                              query  \
# 0      1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1      1b  SELECT COUNT(*) FROM movie_info_idx AS mi_idx ...
# 2      1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 3      1d  SELECT COUNT(*) FROM movie_info_idx AS mi_idx ...
# 4      2a  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# ..    ...                                                ...
# 221   32a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 222   32b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 223   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 224   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 225   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                           query_result  rt_total  run  \
# 0    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...  0.792273    4
# 1    Hash Join (mc.company_type_id = ct.id) <- [Has...  0.553238    4
# 2    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...  0.636802    4
# 3    Hash Join (mc.company_type_id = ct.id) <- [Has...  0.619424    4
# 4    Hash Join (cn.id = mc.company_id) <- [Seq Scan...  1.095501    4
# ..                                                 ...       ...  ...
# 221  Hash Join (mk.keyword_id = k.id) <- [~Merge Jo...  0.010631    4
# 222  Hash Join (mk.keyword_id = k.id) <- [Merge Joi...  0.441383    4
# 223  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...  1.510462    4
# 224  Hash Join (mc1.company_id = cn1.id) <- [Hash J...  0.688176    4
# 225  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...  1.813502    4
#
#            workload                                            explain  \
# 0               ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1               ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2               ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3               ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4               ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..              ...                                                ...
# 221  ues_linearized  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 222  ues_linearized  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 223  ues_linearized  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 224  ues_linearized  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 225  ues_linearized  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...
# 1                                                  NaN
# 2    Hash Join (mi_idx.info_type_id = it.id) <- [Se...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
#
# [259 rows x 8 columns]

# %%
df_ues = df[df.workload == "ues"].copy()
df_ues_lin = df[df.workload == "ues_linearized"].copy()

# %%
df_sqs = df_ues[~df_ues.subquery.isna()].copy()
df_sqs["pruned"] = df_sqs.subquery.apply(lambda sq: sq.any_pruned())
len(df_sqs)
# Out:
# 112

# %%
df_sqs
# Out:
#     label                                              query  \
# 0      1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2      1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 6      2c  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 8      3a  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 9      3b  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..    ...                                                ...
# 110   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 112   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 112   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                           query_result  rt_total  run  \
# 0    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...  0.792273    4
# 2    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...  0.636802    4
# 6    Hash Join (mc.movie_id = t.id) <- [Hash Join (...  0.978012    4
# 8    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...  2.239086    4
# 9    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...  1.081561    4
# ..                                                 ...       ...  ...
# 110  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...  1.637275    4
# 111  Hash Join (mc1.company_id = cn1.id) <- [Hash J...  0.689398    4
# 111  Hash Join (mc1.company_id = cn1.id) <- [Hash J...  0.689398    4
# 112  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...  1.861926    4
# 112  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...  1.861926    4
#
#     workload                                            explain  \
# 0        ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2        ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 6        ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 8        ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 9        ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..       ...                                                ...
# 110      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 111      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 111      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 112      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 112      ues  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery  pruned
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 2    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 6    Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 8    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# 9    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# ..                                                 ...     ...
# 110  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 111  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 112  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 112  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
# [112 rows x 9 columns]

# %%
df_ues_wide = pd.merge(
    df_sqs.drop(columns=["run", "workload"]),
    df_ues_lin.drop(columns=["run", "workload", "subquery"]),
    on="label", how="inner",
    suffixes=("_ues", "_ues_lin"))
df_ues_wide["sq_pred"] = df_ues_wide.subquery.apply(getattr, args=("join_pred",))
df.rename(columns={"rt_total_orig": "rt_ues", "rt_total_trans": "rt_ues_lin"}, inplace=True)
len(df_ues_wide)
# Out:
# 112

# %%
df_ues_wide
# Out:
#     label                                          query_ues  \
# 0      1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1      1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2      2c  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3      3a  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4      3b  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..    ...                                                ...
# 107   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                       query_result_ues  rt_total_ues  \
# 0    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...      0.792273
# 1    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...      0.636802
# 2    Hash Join (mc.movie_id = t.id) <- [Hash Join (...      0.978012
# 3    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...      2.239086
# 4    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...      1.081561
# ..                                                 ...           ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...      1.637275
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...      0.689398
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...      0.689398
# 110  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...      1.861926
# 111  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...      1.861926
#
#                                            explain_ues  \
# 0    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                 ...
# 107  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 108  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 109  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 110  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 111  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery  pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 3    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# 4    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# ..                                                 ...     ...
# 107  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 108  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 109  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
#                                          query_ues_lin  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..                                                 ...
# 107  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                   query_result_ues_lin  rt_total_ues_lin  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...          0.833403
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...          0.653331
# 2    Hash Join (mc.company_id = cn.id) <- [Hash Joi...          1.061340
# 3    Hash Join (mk.keyword_id = k.id) <- [Hash Join...          2.247282
# 4    Hash Join (mk.keyword_id = k.id) <- [Hash Join...          1.099163
# ..                                                 ...               ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...          1.510462
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...          0.688176
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...          0.688176
# 110  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...          1.813502
# 111  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...          1.813502
#
#                                        explain_ues_lin  \
# 0    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                 ...
# 107  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 108  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 109  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 110  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 111  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                              sq_pred
# 0      (mi_idx.info_type_id = it.id)
# 1      (mi_idx.info_type_id = it.id)
# 2            (mc.company_id = cn.id)
# 3             (mk.keyword_id = k.id)
# 4             (mk.keyword_id = k.id)
# ..                               ...
# 107  (mi_idx1.info_type_id = it1.id)
# 108  (mi_idx2.info_type_id = it2.id)
# 109  (mi_idx1.info_type_id = it1.id)
# 110  (mi_idx2.info_type_id = it2.id)
# 111  (mi_idx1.info_type_id = it1.id)
#
# [112 rows x 12 columns]

# %%
def subquery_join_partner(subquery):
    parent = subquery.parent
    left, right = parent.left, parent.right
    partner = left if subquery.join_pred == right.join_pred else right
    return partner

# %%
df_ues_wide["sq_fk_partner"] = df_ues_wide.apply(lambda row: row["query_result_ues"].lookup_subquery(row["sq_pred"]), axis="columns").apply(lambda sq: sq.base_table())
df_ues_wide["sq_fk_table"] = df_ues_wide.apply(lambda row: row["query_result_ues"].lookup_scan(row["sq_fk_partner"]), axis="columns")
df_ues_wide["sq_fk_rows"] = df_ues_wide["sq_fk_table"].apply(lambda tab: tab.proc_rows)

df_ues_wide["sq_join"] = df_ues_wide.apply(lambda row: row["query_result_ues"].lookup_join(row["sq_pred"]), axis="columns")
df_ues_wide["sq_join_rows"] = df_ues_wide["sq_join"].apply(lambda join: join.proc_rows)
df_ues_wide["sq_join_duration"] = df_ues_wide["sq_join"].apply(lambda join: join.exec_time[0] / 1000)

df_ues_wide["sq_join_partner"] = df_ues_wide["sq_join"].apply(subquery_join_partner)
df_ues_wide["sq_join_partner_duration"] = df_ues_wide["sq_join_partner"].apply(lambda join: join.exec_time[0] / 1000)

df_ues_wide["node_pruned_ues"] = df_ues_wide.query_result_ues.apply(lambda plan: plan.any_pruned(exclude_subqueries=True))
df_ues_wide["node_pruned_ues_lin"] = df_ues_wide.query_result_ues_lin.apply(lambda plan: plan.any_pruned(exclude_subqueries=True))

# %%
df_ues_wide
# Out:
#     label                                          query_ues  \
# 0      1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1      1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2      2c  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3      3a  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4      3b  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..    ...                                                ...
# 107   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                       query_result_ues  rt_total_ues  \
# 0    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...      0.792273
# 1    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...      0.636802
# 2    Hash Join (mc.movie_id = t.id) <- [Hash Join (...      0.978012
# 3    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...      2.239086
# 4    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...      1.081561
# ..                                                 ...           ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...      1.637275
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...      0.689398
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...      0.689398
# 110  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...      1.861926
# 111  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...      1.861926
#
#                                            explain_ues  \
# 0    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                 ...
# 107  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 108  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 109  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 110  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 111  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery  pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 3    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# 4    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...    True
# ..                                                 ...     ...
# 107  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 108  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 109  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
#                                          query_ues_lin  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..                                                 ...
# 107  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                   query_result_ues_lin  rt_total_ues_lin  ...  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...          0.833403  ...
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...          0.653331  ...
# 2    Hash Join (mc.company_id = cn.id) <- [Hash Joi...          1.061340  ...
# 3    Hash Join (mk.keyword_id = k.id) <- [Hash Join...          2.247282  ...
# 4    Hash Join (mk.keyword_id = k.id) <- [Hash Join...          1.099163  ...
# ..                                                 ...               ...  ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...          1.510462  ...
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...          0.688176  ...
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...          0.688176  ...
# 110  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...          1.813502  ...
# 111  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...          1.813502  ...
#
#                  sq_fk_partner                  sq_fk_table sq_fk_rows  \
# 0     movie_info_idx AS mi_idx   Seq Scan :: movie_info_idx     789242
# 1     movie_info_idx AS mi_idx   Seq Scan :: movie_info_idx     789242
# 2        movie_companies AS mc  Seq Scan :: movie_companies    1652765
# 3          movie_keyword AS mk  ~Seq Scan~ :: movie_keyword          0
# 4          movie_keyword AS mk  ~Seq Scan~ :: movie_keyword          0
# ..                         ...                          ...        ...
# 107  movie_info_idx AS mi_idx1   Seq Scan :: movie_info_idx     789242
# 108  movie_info_idx AS mi_idx2   Seq Scan :: movie_info_idx        582
# 109  movie_info_idx AS mi_idx1   Seq Scan :: movie_info_idx          3
# 110  movie_info_idx AS mi_idx2   Seq Scan :: movie_info_idx     383765
# 111  movie_info_idx AS mi_idx1   Seq Scan :: movie_info_idx     789242
#
#                                                sq_join  sq_join_rows  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            83
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            83
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...             2
# 3    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...             0
# 4    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...             0
# ..                                                 ...           ...
# 107  Hash Join (mi_idx1.info_type_id = it1.id) <- [...        263052
# 108  Hash Join (mi_idx2.info_type_id = it2.id) <- [...             1
# 109  Hash Join (mi_idx1.info_type_id = it1.id) <- [...             1
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...          6886
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...        263052
#
#     sq_join_duration                                    sq_join_partner  \
# 0           0.107220  Hash Join (t.id = mc.movie_id) <- [Seq Scan ::...
# 1           0.108803  Hash Join (t.id = mc.movie_id) <- [Seq Scan ::...
# 2           0.247829  Hash Join (t.id = mk.movie_id) <- [Seq Scan ::...
# 3           0.000000  Hash Join (mi.movie_id = t.id) <- [Seq Scan ::...
# 4           0.000000  Hash Join (mi.movie_id = t.id) <- [Seq Scan ::...
# ..               ...                                                ...
# 107         0.133475  Hash Join (t2.kind_id = kt2.id) <- [Hash Join ...
# 108         0.000260  Hash Join (mi_idx1.movie_id = t1.id) <- [Hash ...
# 109         0.000017  Hash Join (t2.kind_id = kt2.id) <- [Hash Join ...
# 110         0.140734  Hash Join (mi_idx1.movie_id = t1.id) <- [Hash ...
# 111         0.132812  Hash Join (t2.kind_id = kt2.id) <- [Hash Join ...
#
#      sq_join_partner_duration node_pruned_ues  node_pruned_ues_lin
# 0                    0.658890           False                False
# 1                    0.500195           False                False
# 2                    0.691120           False                False
# 3                    2.222914            True                 True
# 4                    1.068213            True                 True
# ..                        ...             ...                  ...
# 107                  1.467764            True                 True
# 108                  0.670848           False                False
# 109                  0.670828           False                False
# 110                  1.711804            True                 True
# 111                  1.530789            True                 True
#
# [112 rows x 22 columns]

# %%
df_ues_wide["filter_strength_rel"] = df_ues_wide.sq_fk_rows / df_ues_wide.sq_join_rows
df_ues_wide["filter_strength_abs"] = df_ues_wide.sq_fk_rows - df_ues_wide.sq_join_rows
df_ues_wide["sq_speedup_rel"] = df_ues_wide.rt_total_ues_lin / df_ues_wide.rt_total_ues
df_ues_wide["sq_speedup_abs"] = df_ues_wide.rt_total_ues_lin - df_ues_wide.rt_total_ues
df_ues_wide[["label", "subquery", "sq_fk_rows", "sq_join_rows", "rt_total_ues", "rt_total_ues_lin", "filter_strength_rel", "sq_speedup_rel"]]
# Out:
#     label                                           subquery  sq_fk_rows  \
# 0      1a  Hash Join (mi_idx.info_type_id = it.id) <- [Se...      789242
# 1      1c  Hash Join (mi_idx.info_type_id = it.id) <- [Se...      789242
# 2      2c  Hash Join (mc.company_id = cn.id) <- [Seq Scan...     1652765
# 3      3a  ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...           0
# 4      3b  ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...           0
# ..    ...                                                ...         ...
# 107   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...      789242
# 108   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...         582
# 109   33b  Hash Join (mi_idx1.info_type_id = it1.id) <- [...           3
# 110   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...      383765
# 111   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...      789242
#
#      sq_join_rows  rt_total_ues  rt_total_ues_lin  filter_strength_rel  \
# 0              83      0.792273          0.833403          9508.939759
# 1              83      0.636802          0.653331          9508.939759
# 2               2      0.978012          1.061340        826382.500000
# 3               0      2.239086          2.247282                  NaN
# 4               0      1.081561          1.099163                  NaN
# ..            ...           ...               ...                  ...
# 107        263052      1.637275          1.510462             3.000327
# 108             1      0.689398          0.688176           582.000000
# 109             1      0.689398          0.688176             3.000000
# 110          6886      1.861926          1.813502            55.731194
# 111        263052      1.861926          1.813502             3.000327
#
#      sq_speedup_rel
# 0          1.051914
# 1          1.025956
# 2          1.085201
# 3          1.003660
# 4          1.016275
# ..              ...
# 107        0.922546
# 108        0.998227
# 109        0.998227
# 110        0.973993
# 111        0.973993
#
# [112 rows x 8 columns]

# %%
df_export = df_ues_wide.drop(
    columns=["query_result_ues_lin",
             "sq_pred",
             "sq_fk_partner",
             "sq_fk_table",
             "sq_join",
             "sq_join_partner",
             "explain_ues_lin"
            ]).rename(
    columns={"query_result_ues": "ues_plan",
             "explain_ues": "ues_explain",
             "sq_fk_rows": "foreign_key_rows",
             "sq_join_rows": "subquery_rows",
             "rt_total_ues": "runtime_ues",
             "rt_total_ues_lin": "runtime_ues_linear",
             "sq_speedup_rel": "ues_speedup_rel",
             "sq_speedup_abs": "ues_speedup_abs",
             "query_ues": "query_ues",
             "query_ues_lin": "query_ues_linear",
             "sq_join_duration": "subquery_runtime",
             "sq_join_partner_duration": "subquery_partner_runtime",
             "pruned": "subquery_pruned",
             "node_pruned_ues": "ues_pruned",
             "node_pruned_ues_lin": "ues_linear_pruned"
            })
df_export["tables"] = df_export.query_ues.apply(lambda q: json.dumps([tab.full_name for tab in q.collect_tables()]))
df_export["subquery_tables"] = df_export.subquery.apply(lambda sq: sq.lookup_subquery(sq.join_pred).collect_tables()).apply(lambda sq_tabs: json.dumps([tab.full_name for tab in sq_tabs]))

df_export.ues_explain = df_export.ues_explain.apply(json.dumps)

df_export.to_csv("workloads/job-ues-eval-linearization.csv", index=False)
df_export
# Out:
#     label                                          query_ues  \
# 0      1a  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1      1c  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2      2c  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3      3a  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4      3b  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..    ...                                                ...
# 107   33a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 108   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 109   33b  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                               ues_plan  runtime_ues  \
# 0    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...     0.792273
# 1    Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...     0.636802
# 2    Hash Join (mc.movie_id = t.id) <- [Hash Join (...     0.978012
# 3    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...     2.239086
# 4    Hash Join (mk.movie_id = t.id) <- [~Hash Join~...     1.081561
# ..                                                 ...          ...
# 107  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...     1.637275
# 108  Hash Join (mc1.company_id = cn1.id) <- [Hash J...     0.689398
# 109  Hash Join (mc1.company_id = cn1.id) <- [Hash J...     0.689398
# 110  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...     1.861926
# 111  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...     1.861926
#
#                                            ues_explain  \
# 0    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 1    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 2    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 3    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 4    [{"Plan": {"Node Type": "Aggregate", "Strategy...
# ..                                                 ...
# 107  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 108  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 109  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 110  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 111  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                               subquery  subquery_pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...            False
# 3    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...             True
# 4    ~Hash Join~ (mk.keyword_id = k.id) <- [~Seq Sc...             True
# ..                                                 ...              ...
# 107  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
# 108  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 109  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
#
#                                       query_ues_linear  runtime_ues_linear  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...            0.833403
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...            0.653331
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...            1.061340
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...            2.247282
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...            1.099163
# ..                                                 ...                 ...
# 107  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...            1.510462
# 108  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...            0.688176
# 109  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...            0.688176
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...            1.813502
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...            1.813502
#
#      foreign_key_rows  ...  subquery_runtime  subquery_partner_runtime  \
# 0              789242  ...          0.107220                  0.658890
# 1              789242  ...          0.108803                  0.500195
# 2             1652765  ...          0.247829                  0.691120
# 3                   0  ...          0.000000                  2.222914
# 4                   0  ...          0.000000                  1.068213
# ..                ...  ...               ...                       ...
# 107            789242  ...          0.133475                  1.467764
# 108               582  ...          0.000260                  0.670848
# 109                 3  ...          0.000017                  0.670828
# 110            383765  ...          0.140734                  1.711804
# 111            789242  ...          0.132812                  1.530789
#
#      ues_pruned  ues_linear_pruned  filter_strength_rel  filter_strength_abs  \
# 0         False              False          9508.939759               789159
# 1         False              False          9508.939759               789159
# 2         False              False        826382.500000              1652763
# 3          True               True                  NaN                    0
# 4          True               True                  NaN                    0
# ..          ...                ...                  ...                  ...
# 107        True               True             3.000327               526190
# 108       False              False           582.000000                  581
# 109       False              False             3.000000                    2
# 110        True               True            55.731194               376879
# 111        True               True             3.000327               526190
#
#      ues_speedup_rel  ues_speedup_abs  \
# 0           1.051914         0.041130
# 1           1.025956         0.016529
# 2           1.085201         0.083328
# 3           1.003660         0.008196
# 4           1.016275         0.017602
# ..               ...              ...
# 107         0.922546        -0.126813
# 108         0.998227        -0.001222
# 109         0.998227        -0.001222
# 110         0.973993        -0.048424
# 111         0.973993        -0.048424
#
#                                                 tables  \
# 0    ["movie_companies", "company_type", "title", "...
# 1    ["movie_companies", "company_type", "title", "...
# 2    ["movie_keyword", "keyword", "title", "movie_c...
# 3    ["movie_info", "title", "movie_keyword", "keyw...
# 4    ["movie_info", "title", "movie_keyword", "keyw...
# ..                                                 ...
# 107  ["movie_link", "link_type", "title", "title", ...
# 108  ["movie_link", "link_type", "title", "title", ...
# 109  ["movie_link", "link_type", "title", "title", ...
# 110  ["movie_link", "link_type", "title", "title", ...
# 111  ["movie_link", "link_type", "title", "title", ...
#
#                          subquery_tables
# 0        ["movie_info_idx", "info_type"]
# 1        ["movie_info_idx", "info_type"]
# 2    ["movie_companies", "company_name"]
# 3           ["movie_keyword", "keyword"]
# 4           ["movie_keyword", "keyword"]
# ..                                   ...
# 107      ["movie_info_idx", "info_type"]
# 108      ["movie_info_idx", "info_type"]
# 109      ["movie_info_idx", "info_type"]
# 110      ["movie_info_idx", "info_type"]
# 111      ["movie_info_idx", "info_type"]
#
# [112 rows x 21 columns]

# %% [markdown]
# ## Some sanity checks for the export data set

# %%
df_export.groupby("label")[["label"]].count().rename(columns={"label": "count"}).reset_index().sort_values(by="count", ascending=False)
# Out:
#    label  count
# 58   31c      3
# 56   31a      3
# 39   25c      2
# 61   33a      2
# 57   31b      2
# ..   ...    ...
# 35   23c      1
# 36   24b      1
# 38   25b      1
# 40   26a      1
# 78    8d      1
#
# [79 rows x 2 columns]

# %%
df_export.loc[df_export.filter_strength.isna() & ~df_export.subquery_pruned]
# Out:
# Empty DataFrame
# Columns: [label, query_ues, ues_plan, runtime_ues, ues_explain, subquery, subquery_pruned, query_flat, runtime_flat, foreign_key_rows, rows_after_join, subquery_runtime, subquery_partner_runtime, ues_pruned, flat_pruned, filter_strength, ues_speedup, tables, subquery_tables]
# Index: []

# %%
df_export.loc[df_export.label == "6b"]
# Out:
#    label                                          query_ues  \
# 10    6b  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
#
#                                              ues_plan  runtime_ues  \
# 10  Hash Join (ci.movie_id = t.id) <- [Hash Join (...     0.536543
#
#                                           ues_explain  \
# 10  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                              subquery  subquery_pruned  \
# 10  Hash Join (ci.person_id = n.id) <- [~Seq Scan~...             True
#
#                                            query_flat  runtime_flat  \
# 10  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...      2.252002
#
#     foreign_key_rows  rows_after_join  subquery_runtime  \
# 10                 0                0          0.181875
#
#     subquery_partner_runtime  ues_pruned  flat_pruned  filter_strength  \
# 10                  0.349454        True        False              NaN
#
#     ues_speedup                                             tables  \
# 10     4.197244  ["movie_keyword", "keyword", "title", "cast_in...
#
#           subquery_tables
# 10  ["cast_info", "name"]

# %%
df_export.loc[df_export.label == "20b"].iloc[0].query_ues
# Out:
# SELECT COUNT(*) FROM complete_cast AS cc JOIN comp_cast_type AS cct1 ON cct1.kind = 'cast' AND cct1.id = cc.subject_id JOIN comp_cast_type AS cct2 ON cct2.kind LIKE '%complete%' AND cct2.id = cc.status_id JOIN title AS t ON t.production_year > 2000 AND t.id = cc.movie_id JOIN kind_type AS kt ON kt.kind = 'movie' AND kt.id = t.kind_id JOIN (SELECT movie_id FROM movie_keyword AS mk JOIN keyword AS k ON k.keyword IN ('superhero', 'sequel', 'second-part', 'marvel-comics', 'based-on-comic', 'tv-special', 'fight', 'violence') AND k.id = mk.keyword_id) AS t_mk ON t_mk.movie_id = cc.movie_id JOIN (SELECT person_id, movie_id FROM cast_info AS ci JOIN name AS n ON n.name LIKE '%downey%robert%' AND n.id = ci.person_id JOIN char_name AS chn ON chn.name NOT LIKE '%sherlock%' AND (chn.name LIKE '%tony%stark%' OR chn.name LIKE '%iron%man%') AND chn.id = ci.person_role_id) AS t_ci ON t_ci.movie_id = t_mk.movie_id

# %%
print(df_export.loc[df_export.label == "6b"].iloc[0].ues_plan.pretty_print(include_filter=True))
# Out:
# Hash Join (ci.movie_id = t.id)
#   <- [SQ] Hash Join (ci.person_id = n.id)
#     <- [PRUNED] Seq Scan :: cast_info
#     <- Seq Scan :: name (((name)::text ~~ '%downey%robert%'::text))
#   <- Hash Join (t.id = mk.movie_id)
#     <- Seq Scan :: title ((production_year > 2014))
#     <- Hash Join (mk.keyword_id = k.id)
#       <- Seq Scan :: movie_keyword
#       <- Seq Scan :: keyword (((keyword)::text = ANY ('{superhero,sequel,second-part,marvel-comics,based-on-comic,tv-special,fight,violence}'::text[])))

# %%
df_export.loc[df_export.label == "6b"].iloc[0].ues_explain
# Out:
# '[{"Plan": {"Node Type": "Aggregate", "Strategy": "Plain", "Partial Mode": "Simple", "Parallel Aware": false, "Async Capable": false, "Startup Cost": 622730.99, "Total Cost": 622731.0, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 534.419, "Actual Total Time": 535.652, "Actual Rows": 1, "Actual Loops": 1, "Plans": [{"Node Type": "Gather", "Parent Relationship": "Outer", "Parallel Aware": false, "Async Capable": false, "Startup Cost": 179377.81, "Total Cost": 622730.98, "Plan Rows": 1, "Plan Width": 0, "Actual Startup Time": 534.414, "Actual Total Time": 535.647, "Actual Rows": 0, "Actual Loops": 1, "Workers Planned": 2, "Workers Launched": 2, "Single Copy": false, "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 178377.81, "Total Cost": 621730.88, "Plan Rows": 1, "Plan Width": 0, "Actual Startup Time": 531.817, "Actual Total Time": 531.823, "Actual Rows": 0, "Actual Loops": 3, "Inner Unique": false, "Hash Cond": "(ci.movie_id = t.id)", "Workers": [], "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 77320.47, "Total Cost": 520667.86, "Plan Rows": 1511, "Plan Width": 4, "Actual Startup Time": 181.873, "Actual Total Time": 181.875, "Actual Rows": 0, "Actual Loops": 3, "Inner Unique": true, "Hash Cond": "(ci.person_id = n.id)", "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "cast_info", "Alias": "ci", "Startup Cost": 0.0, "Total Cost": 403705.1, "Plan Rows": 15101810, "Plan Width": 8, "Actual Startup Time": 0.0, "Actual Total Time": 0.0, "Actual Rows": 0, "Actual Loops": 0, "Workers": []}, {"Node Type": "Hash", "Parent Relationship": "Inner", "Parallel Aware": true, "Async Capable": false, "Startup Cost": 77318.29, "Total Cost": 77318.29, "Plan Rows": 174, "Plan Width": 4, "Actual Startup Time": 181.862, "Actual Total Time": 181.863, "Actual Rows": 0, "Actual Loops": 3, "Hash Buckets": 1024, "Original Hash Buckets": 1024, "Hash Batches": 1, "Original Hash Batches": 1, "Peak Memory Usage": 0, "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "name", "Alias": "n", "Startup Cost": 0.0, "Total Cost": 77318.29, "Plan Rows": 174, "Plan Width": 4, "Actual Startup Time": 181.83, "Actual Total Time": 181.83, "Actual Rows": 0, "Actual Loops": 3, "Filter": "((name)::text ~~ \'%downey%robert%\'::text)", "Rows Removed by Filter": 1389164, "Workers": []}]}]}, {"Node Type": "Hash", "Parent Relationship": "Inner", "Parallel Aware": true, "Async Capable": false, "Startup Cost": 101057.33, "Total Cost": 101057.33, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 349.542, "Actual Total Time": 349.546, "Actual Rows": 12, "Actual Loops": 3, "Hash Buckets": 1024, "Original Hash Buckets": 1024, "Hash Batches": 1, "Original Hash Batches": 1, "Peak Memory Usage": 104, "Workers": [], "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 51885.81, "Total Cost": 101057.33, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 274.84, "Actual Total Time": 349.454, "Actual Rows": 12, "Actual Loops": 3, "Inner Unique": false, "Hash Cond": "(t.id = mk.movie_id)", "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "title", "Alias": "t", "Startup Cost": 0.0, "Total Cost": 49166.29, "Plan Rows": 835, "Plan Width": 4, "Actual Startup Time": 0.272, "Actual Total Time": 77.493, "Actual Rows": 146, "Actual Loops": 3, "Filter": "(production_year > 2014)", "Rows Removed by Filter": 842625, "Workers": []}, {"Node Type": "Hash", "Parent Relationship": "Inne ...

# %%
df_export.loc[df_export.label == "33c"]
# Out:
#     label                                          query_ues  \
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                               ues_plan  runtime_ues  \
# 110  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.208609
# 111  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.208609
#
#                                            ues_explain  \
# 110  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 111  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                               subquery  subquery_pruned  \
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
#
#                                             query_flat  runtime_flat  \
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.189302
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.189302
#
#      foreign_key_rows  rows_after_join  subquery_runtime  \
# 110            351960            18374          0.121368
# 111            690018           229962          0.114501
#
#      subquery_partner_runtime  ues_pruned  flat_pruned  filter_strength  \
# 110                  0.695499       False        False        19.155328
# 111                  0.564965       False        False         3.000574
#
#      ues_speedup                                             tables  \
# 110     0.984025  ["movie_link", "link_type", "title", "title", ...
# 111     0.984025  ["movie_link", "link_type", "title", "title", ...
#
#                      subquery_tables
# 110  ["movie_info_idx", "info_type"]
# 111  ["movie_info_idx", "info_type"]

# %%
df_export.loc[df_export.label == "33c"].iloc[0].query_ues
# Out:
# SELECT COUNT(*) FROM movie_link AS ml JOIN link_type AS lt ON lt.link IN ('sequel', 'follows', 'followed by') AND lt.id = ml.link_type_id JOIN title AS t2 ON t2.production_year BETWEEN 2000 AND 2010 AND t2.id = ml.linked_movie_id JOIN title AS t1 ON t1.id = ml.movie_id JOIN kind_type AS kt1 ON kt1.kind IN ('tv series', 'episode') AND kt1.id = t1.kind_id JOIN kind_type AS kt2 ON kt2.kind IN ('tv series', 'episode') AND kt2.id = t2.kind_id JOIN (SELECT movie_id FROM movie_info_idx AS mi_idx1 JOIN info_type AS it1 ON it1.info = 'rating' AND it1.id = mi_idx1.info_type_id) AS t_mi_idx1 ON t_mi_idx1.movie_id = ml.movie_id JOIN (SELECT movie_id FROM movie_info_idx AS mi_idx2 JOIN info_type AS it2 ON it2.info = 'rating' AND it2.id = mi_idx2.info_type_id AND mi_idx2.info < '3.5') AS t_mi_idx2 ON t_mi_idx2.movie_id = ml.linked_movie_id JOIN movie_companies AS mc2 ON mc2.movie_id = ml.linked_movie_id JOIN company_name AS cn2 ON cn2.id = mc2.company_id JOIN movie_companies AS mc1 ON mc1.movie_id = ml.movie_id JOIN company_name AS cn1 ON cn1.country_code <> '[us]' AND cn1.id = mc1.company_id

# %%
print(df_export.loc[df_export.label == "33c"].iloc[0].ues_plan.pretty_print(include_filter=True))
# Out:
# Hash Join (cn1.id = mc1.company_id)
#   <- Seq Scan :: company_name (((country_code)::text <> '[us]'::text))
#   <- Hash Join (mc1.movie_id = t1.id)
#     <- Seq Scan :: movie_companies
#     <- Hash Join (cn2.id = mc2.company_id)
#       <- Seq Scan :: company_name
#       <- Hash Join (mc2.movie_id = t2.id)
#         <- Seq Scan :: movie_companies
#         <- Hash Join (mi_idx2.movie_id = t2.id)
#           <- [SQ] Hash Join (mi_idx2.info_type_id = it2.id)
#             <- Seq Scan :: movie_info_idx (((info)::text < '3.5'::text))
#             <- Seq Scan :: info_type (((info)::text = 'rating'::text))
#           <- Hash Join (mi_idx1.movie_id = t1.id)
#             <- [SQ] Hash Join (mi_idx1.info_type_id = it1.id)
#               <- Seq Scan :: movie_info_idx
#               <- Seq Scan :: info_type (((info)::text = 'rating'::text))
#             <- Hash Join (t2.kind_id = kt2.id)
#               <- Hash Join (t1.kind_id = kt1.id)
#                 <- Merge Join (t1.id = ml.movie_id)
#                   <- Index Scan :: title
#                   <- Hash Join (ml.linked_movie_id = t2.id)
#                     <- Hash Join (ml.link_type_id = lt.id)
#                       <- Seq Scan :: movie_link
#                       <- Seq Scan :: link_type (((link)::text = ANY ('{sequel,follows,"followed by"}'::text[])))
#                     <- Seq Scan :: title (((production_year >= 2000) AND (production_year <= 2010)))
#                 <- Seq Scan :: kind_type (((kind)::text = ANY ('{"tv series",episode}'::text[])))
#               <- Seq Scan :: kind_type (((kind)::text = ANY ('{"tv series",episode}'::text[])))
