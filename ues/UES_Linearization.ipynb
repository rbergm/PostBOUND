# %% [markdown]
# # UES workload analysis

# %% [markdown]
# ## Data loading

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import re
import warnings

import natsort
import numpy as np
import pandas as pd
import seaborn as sns

from transform import db, mosp
from postgres import explain
from analysis import selection

# %%
sns.set_theme(style="whitegrid")

# %%
df_base = pd.read_csv("workloads/job-ues-results-rebuild.csv")
df_lin = pd.read_csv("workloads/job-ues-results-linearized.csv")

# %% [markdown]
# ## Initial analysis

# %% [markdown]
# Get a rough overview of the workload performance:

# %%
df_base.groupby("run")["query_rt_total"].sum()
# Out:
# run
# 1    412.299860
# 2    411.238048
# 3    406.238064
# 4    409.906597
# 5    409.552837
# Name: query_rt_total, dtype: float64

# %%
df_lin.groupby("run")["query_rt_total"].sum()
# Out:
# run
# 1    412.487329
# 2    407.745956
# 3    406.529721
# 4    402.119050
# 5    407.860975
# Name: query_rt_total, dtype: float64

# %%
df_base = selection.best_query_repetition(df_base, "label", performance_col="query_rt_total").copy()
df_lin = selection.best_query_repetition(df_lin, "label", performance_col="query_rt_total").copy()

# %%
df_base["workload"] = "ues"
df_lin["workload"] = "ues_linearized"
df = pd.concat([df_base, df_lin])
df.sort_values(by="label", key=lambda _: np.argsort(natsort.index_natsorted(df["label"])),
               inplace=True)
df
# Out:
#                                                 query label  \
# 38  SELECT COUNT(*) FROM movie_companies AS mc JOI...    1a
# 38  SELECT COUNT(*) FROM movie_companies AS mc JOI...    1a
# 39  SELECT COUNT(*) FROM movie_info_idx AS mi_idx ...    1b
# 39  SELECT COUNT(*) FROM movie_info_idx AS mi_idx ...    1b
# 40  SELECT COUNT(*) FROM movie_companies AS mc JOI...    1c
# ..                                                ...   ...
# 84  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33a
# 85  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 85  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 86  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
# 86  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
#
#     optimization_time                                       query_result  \
# 38           0.004274  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 38           0.004410  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 39           0.003848  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 39           0.003347  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 40           0.005587  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# ..                ...                                                ...
# 84           0.363256  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 85           0.009899  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 85           0.009747  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 86           0.010593  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 86           0.010535  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#     query_rt_total  run        workload
# 38        1.050499    3             ues
# 38        0.992252    1  ues_linearized
# 39        0.555610    4             ues
# 39        0.553253    3  ues_linearized
# 40        0.737995    1             ues
# ..             ...  ...             ...
# 84        1.583707    2  ues_linearized
# 85        0.664327    1             ues
# 85        0.589906    2  ues_linearized
# 86        1.823239    2             ues
# 86        1.756614    1  ues_linearized
#
# [226 rows x 7 columns]

# %% [markdown]
# ## Feature calculation

# %%
def parse_query_plans(sample: pd.Series) -> explain.PlanNode:
    query, plan, workload = sample["query"], sample["query_result"], sample["workload"]
    if workload == "ues":
        parsed_plan = explain.parse_explain_analyze(query, plan)
    elif workload == "ues_linearized":
        parsed_plan = explain.parse_explain_analyze(query, plan, with_subqueries=False)
    else:
        warnings.warn("Unknown workload '{}', assuming no subqueries".format(workload))
        parsed_plan = explain.parse_explain_analyze(query, plan, with_subqueries=False)
    return parsed_plan

# %%
df.query_result = df.query_result.apply(json.loads)
df["query"] = df["query"].apply(mosp.MospQuery.parse)
df["explain"] = df.query_result
df.query_result = df.apply(parse_query_plans, axis="columns")
df["subquery"] = df.query_result.apply(explain.PlanNode.extract_subqueries)
df = df.explode("subquery")
df
# Out:
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:495: UserWarning: Unknown node type: Hash
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:495: UserWarning: Unknown node type: Aggregate
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:495: UserWarning: Unknown node type: Gather
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:495: UserWarning: Unknown node type: Sort
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:495: UserWarning: Unknown node type: Gather Merge
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:495: UserWarning: Unknown node type: Materialize
#   warnings.warn("Unknown node type: {}".format(node_type))
#                                                 query label  \
# 38  SELECT COUNT(*) FROM movie_companies AS mc JOI...    1a
# 38  SELECT COUNT(*) FROM movie_companies AS mc JOI...    1a
# 39  SELECT COUNT(*) FROM movie_info_idx AS mi_idx ...    1b
# 39  SELECT COUNT(*) FROM movie_info_idx AS mi_idx ...    1b
# 40  SELECT COUNT(*) FROM movie_companies AS mc JOI...    1c
# ..                                                ...   ...
# 85  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 85  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 86  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
# 86  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
# 86  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
#
#     optimization_time                                       query_result  \
# 38           0.004274  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 38           0.004410  Hash Join (mi_idx.info_type_id = it.id) <- [Ha...
# 39           0.003848  Hash Join (mc.company_type_id = ct.id) <- [Has...
# 39           0.003347  Hash Join (mc.company_type_id = ct.id) <- [Has...
# 40           0.005587  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# ..                ...                                                ...
# 85           0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 85           0.009747  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 86           0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 86           0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 86           0.010535  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
#
#     query_rt_total  run        workload  \
# 38        1.050499    3             ues
# 38        0.992252    1  ues_linearized
# 39        0.555610    4             ues
# 39        0.553253    3  ues_linearized
# 40        0.737995    1             ues
# ..             ...  ...             ...
# 85        0.664327    1             ues
# 85        0.589906    2  ues_linearized
# 86        1.823239    2             ues
# 86        1.823239    2             ues
# 86        1.756614    1  ues_linearized
#
#                                               explain  \
# 38  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 38  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 39  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 39  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 40  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                ...
# 85  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 85  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 86  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 86  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 86  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                              subquery
# 38  Hash Join (mi_idx.info_type_id = it.id) <- [Se...
# 38                                                NaN
# 39                                                NaN
# 39                                                NaN
# 40  Hash Join (mi_idx.info_type_id = it.id) <- [Se...
# ..                                                ...
# 85  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 85                                                NaN
# 86  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 86  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 86                                                NaN
#
# [257 rows x 9 columns]

# %%
df_ues = df[df.workload == "ues"].copy()
df_ues_lin = df[df.workload == "ues_linearized"].copy()

# %%
df_sqs = df_ues[~df_ues.subquery.isna()].copy()
df_sqs["pruned"] = df_sqs.subquery.apply(lambda sq: sq.any_pruned())
len(df_sqs)
# Out:
# 105

# %%
df_sqs
# Out:
#                                                 query label  \
# 38  SELECT COUNT(*) FROM movie_companies AS mc JOI...    1a
# 40  SELECT COUNT(*) FROM movie_companies AS mc JOI...    1c
# 74  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...    2c
# 87  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...    3a
# 88  SELECT COUNT(*) FROM movie_info AS mi JOIN tit...    3b
# ..                                                ...   ...
# 84  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33a
# 85  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 85  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 86  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
# 86  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
#
#     optimization_time                                       query_result  \
# 38           0.004274  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 40           0.005587  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 74           0.003486  Hash Join (mc.movie_id = t.id) <- [Hash Join (...
# 87           0.002976  Hash Join (mk.movie_id = t.id) <- [Hash Join (...
# 88           0.003484  Hash Join (mk.movie_id = t.id) <- [Hash Join (...
# ..                ...                                                ...
# 84           0.182369  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 85           0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 85           0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 86           0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 86           0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
#
#     query_rt_total  run workload  \
# 38        1.050499    3      ues
# 40        0.737995    1      ues
# 74        0.975779    1      ues
# 87        2.917895    5      ues
# 88        1.606580    3      ues
# ..             ...  ...      ...
# 84        1.629256    1      ues
# 85        0.664327    1      ues
# 85        0.664327    1      ues
# 86        1.823239    2      ues
# 86        1.823239    2      ues
#
#                                               explain  \
# 38  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 40  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 74  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 87  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 88  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                ...
# 84  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 85  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 85  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 86  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 86  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                              subquery  pruned
# 38  Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 40  Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 74  Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 87  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# 88  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# ..                                                ...     ...
# 84  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 85  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 85  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 86  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 86  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
# [105 rows x 10 columns]

# %%
df_ues_wide = pd.merge(
    df_sqs.drop(columns=["run", "workload"]),
    df_ues_lin.drop(columns=["run", "workload", "subquery"]),
    on="label", how="inner",
    suffixes=("_ues", "_ues_lin"))
df_ues_wide["sq_pred"] = df_ues_wide.subquery.apply(getattr, args=("join_pred",))
df_ues_wide.rename(columns={"query_rt_total_ues": "rt_ues", "query_rt_total_ues_lin": "rt_ues_lin"}, inplace=True)
len(df_ues_wide)
# Out:
# 105

# %%
df_ues_wide
# Out:
#                                              query_ues label  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...    1a
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...    1c
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...    2c
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...    3a
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...    3b
# ..                                                 ...   ...
# 100  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33a
# 101  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 102  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 103  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
# 104  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
#
#      optimization_time_ues                                   query_result_ues  \
# 0                 0.004274  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 1                 0.005587  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 2                 0.003486  Hash Join (mc.movie_id = t.id) <- [Hash Join (...
# 3                 0.002976  Hash Join (mk.movie_id = t.id) <- [Hash Join (...
# 4                 0.003484  Hash Join (mk.movie_id = t.id) <- [Hash Join (...
# ..                     ...                                                ...
# 100               0.182369  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 101               0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 102               0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 103               0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 104               0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
#
#        rt_ues                                        explain_ues  \
# 0    1.050499  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    0.737995  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    0.975779  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    2.917895  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    1.606580  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..        ...                                                ...
# 100  1.629256  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 101  0.664327  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 102  0.664327  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 103  1.823239  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 104  1.823239  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery  pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 3    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# 4    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# ..                                                 ...     ...
# 100  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 101  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 102  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 103  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 104  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
#                                          query_ues_lin  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..                                                 ...
# 100  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 101  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 102  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 103  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 104  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#      optimization_time_ues_lin  \
# 0                     0.004410
# 1                     0.004804
# 2                     0.002770
# 3                     0.002648
# 4                     0.004370
# ..                         ...
# 100                   0.363256
# 101                   0.009747
# 102                   0.009747
# 103                   0.010535
# 104                   0.010535
#
#                                   query_result_ues_lin  rt_ues_lin  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...    0.992252
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Ha...    0.701607
# 2    Hash Join (mc.company_id = cn.id) <- [Hash Joi...    1.028141
# 3    Hash Join (mk.keyword_id = k.id) <- [Hash Join...    2.656466
# 4    Hash Join (mk.keyword_id = k.id) <- [Hash Join...    1.438635
# ..                                                 ...         ...
# 100  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...    1.583707
# 101  Hash Join (mc1.company_id = cn1.id) <- [Hash J...    0.589906
# 102  Hash Join (mc1.company_id = cn1.id) <- [Hash J...    0.589906
# 103  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...    1.756614
# 104  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...    1.756614
#
#                                        explain_ues_lin  \
# 0    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..                                                 ...
# 100  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 101  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 102  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 103  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 104  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                              sq_pred
# 0      (mi_idx.info_type_id = it.id)
# 1      (mi_idx.info_type_id = it.id)
# 2            (mc.company_id = cn.id)
# 3             (mk.keyword_id = k.id)
# 4             (mk.keyword_id = k.id)
# ..                               ...
# 100  (mi_idx1.info_type_id = it1.id)
# 101  (mi_idx2.info_type_id = it2.id)
# 102  (mi_idx1.info_type_id = it1.id)
# 103  (mi_idx2.info_type_id = it2.id)
# 104  (mi_idx1.info_type_id = it1.id)
#
# [105 rows x 14 columns]

# %%
def subquery_join_partner(subquery):
    parent = subquery.parent
    left, right = parent.left, parent.right
    partner = left if subquery.join_pred == right.join_pred else right
    return partner

# %%
df_ues_wide["sq_fk_partner"] = df_ues_wide.apply(lambda row: row["query_result_ues"].lookup_subquery(row["sq_pred"]), axis="columns").apply(lambda sq: sq.base_table())
df_ues_wide["sq_fk_table"] = df_ues_wide.apply(lambda row: row["query_result_ues"].lookup_scan(row["sq_fk_partner"]), axis="columns")
df_ues_wide["sq_fk_rows"] = df_ues_wide["sq_fk_table"].apply(lambda tab: tab.incoming_rows(fallback_live=True))

df_ues_wide["sq_join"] = df_ues_wide.apply(lambda row: row["query_result_ues"].lookup_join(row["sq_pred"]), axis="columns")
df_ues_wide["sq_join_rows"] = df_ues_wide["sq_join"].apply(lambda join: join.lookup_subquery().count_result_tuples())
df_ues_wide["sq_join_duration"] = df_ues_wide["sq_join"].apply(lambda join: join.exec_time)

df_ues_wide["sq_join_partner"] = df_ues_wide["sq_join"].apply(subquery_join_partner)
df_ues_wide["sq_join_partner_duration"] = df_ues_wide["sq_join_partner"].apply(lambda join: join.exec_time)

df_ues_wide["node_pruned_ues"] = df_ues_wide.query_result_ues.apply(lambda plan: plan.any_pruned(exclude_subqueries=True))
df_ues_wide["node_pruned_ues_lin"] = df_ues_wide.query_result_ues_lin.apply(lambda plan: plan.any_pruned(exclude_subqueries=True))

# %%
df_ues_wide
# Out:
#                                              query_ues label  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...    1a
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...    1c
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...    2c
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...    3a
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...    3b
# ..                                                 ...   ...
# 100  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33a
# 101  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 102  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 103  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
# 104  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
#
#      optimization_time_ues                                   query_result_ues  \
# 0                 0.004274  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 1                 0.005587  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 2                 0.003486  Hash Join (mc.movie_id = t.id) <- [Hash Join (...
# 3                 0.002976  Hash Join (mk.movie_id = t.id) <- [Hash Join (...
# 4                 0.003484  Hash Join (mk.movie_id = t.id) <- [Hash Join (...
# ..                     ...                                                ...
# 100               0.182369  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 101               0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 102               0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 103               0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 104               0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
#
#        rt_ues                                        explain_ues  \
# 0    1.050499  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 1    0.737995  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 2    0.975779  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 3    2.917895  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 4    1.606580  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# ..        ...                                                ...
# 100  1.629256  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 101  0.664327  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 102  0.664327  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 103  1.823239  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# 104  1.823239  [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
#
#                                               subquery  pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...   False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...   False
# 3    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# 4    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...   False
# ..                                                 ...     ...
# 100  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 101  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 102  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
# 103  Hash Join (mi_idx2.info_type_id = it2.id) <- [...   False
# 104  Hash Join (mi_idx1.info_type_id = it1.id) <- [...   False
#
#                                          query_ues_lin  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..                                                 ...
# 100  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 101  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 102  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 103  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 104  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#      optimization_time_ues_lin  ...              sq_fk_partner  \
# 0                     0.004410  ...   movie_info_idx AS mi_idx
# 1                     0.004804  ...   movie_info_idx AS mi_idx
# 2                     0.002770  ...      movie_companies AS mc
# 3                     0.002648  ...        movie_keyword AS mk
# 4                     0.004370  ...        movie_keyword AS mk
# ..                         ...  ...                        ...
# 100                   0.363256  ...  movie_info_idx AS mi_idx1
# 101                   0.009747  ...  movie_info_idx AS mi_idx2
# 102                   0.009747  ...  movie_info_idx AS mi_idx1
# 103                   0.010535  ...  movie_info_idx AS mi_idx2
# 104                   0.010535  ...  movie_info_idx AS mi_idx1
#
#                      sq_fk_table sq_fk_rows  \
# 0     Seq Scan :: movie_info_idx    2367725
# 1     Seq Scan :: movie_info_idx    2367725
# 2    Seq Scan :: movie_companies    4958296
# 3      Seq Scan :: movie_keyword    7480087
# 4      Seq Scan :: movie_keyword    7480087
# ..                           ...        ...
# 100   Seq Scan :: movie_info_idx    2367725
# 101   Seq Scan :: movie_info_idx    2367725
# 102   Seq Scan :: movie_info_idx    2367725
# 103   Seq Scan :: movie_info_idx    2367725
# 104   Seq Scan :: movie_info_idx    2367725
#
#                                                sq_join sq_join_rows  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...          250
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...          250
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...            7
# 3    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...        14050
# 4    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...        14050
# ..                                                 ...          ...
# 100  Hash Join (mi_idx1.info_type_id = it1.id) <- [...       789155
# 101  Hash Join (mi_idx2.info_type_id = it2.id) <- [...        13726
# 102  Hash Join (mi_idx1.info_type_id = it1.id) <- [...       789155
# 103  Hash Join (mi_idx2.info_type_id = it2.id) <- [...        20658
# 104  Hash Join (mi_idx1.info_type_id = it1.id) <- [...       789155
#
#     sq_join_duration                                    sq_join_partner  \
# 0           0.119231  Hash Join (mc.movie_id = t.id) <- [Hash Join (...
# 1           0.108347  Hash Join (mc.movie_id = t.id) <- [Hash Join (...
# 2           0.244117  Hash Join (t.id = mk.movie_id) <- [Seq Scan ::...
# 3           0.362651  Hash Join (mi.movie_id = t.id) <- [Seq Scan ::...
# 4           0.385987  Hash Join (mi.movie_id = t.id) <- [Seq Scan ::...
# ..               ...                                                ...
# 100         0.135864  Hash Join (t1.kind_id = kt1.id) <- [Merge Join...
# 101         0.000268  Hash Join (mi_idx1.movie_id = t1.id) <- [Hash ...
# 102         0.000017  Hash Join (t1.kind_id = kt1.id) <- [Merge Join...
# 103         0.141106  Hash Join (mi_idx1.movie_id = t1.id) <- [Hash ...
# 104         0.132114  Hash Join (t1.kind_id = kt1.id) <- [Merge Join...
#
#     sq_join_partner_duration  node_pruned_ues  node_pruned_ues_lin
# 0                   0.885482            False                False
# 1                   0.602376            False                False
# 2                   0.691910            False                False
# 3                   2.517675            False                False
# 4                   1.197622            False                False
# ..                       ...              ...                  ...
# 100                 1.467996             True                 True
# 101                 0.645468            False                False
# 102                 0.645448            False                False
# 103                 1.671990             True                 True
# 104                 1.501128             True                 True
#
# [105 rows x 24 columns]

# %%
df_ues_wide["filter_strength_rel"] = df_ues_wide.sq_fk_rows / df_ues_wide.sq_join_rows
df_ues_wide["filter_strength_abs"] = df_ues_wide.sq_fk_rows - df_ues_wide.sq_join_rows
df_ues_wide["sq_speedup_rel"] = df_ues_wide.rt_ues_lin / df_ues_wide.rt_ues
df_ues_wide["sq_speedup_abs"] = df_ues_wide.rt_ues_lin - df_ues_wide.rt_ues
df_ues_wide[["label", "subquery", "sq_fk_rows", "sq_join_rows", "rt_ues", "rt_ues_lin", "filter_strength_rel", "sq_speedup_rel"]]
# Out:
#     label                                           subquery  sq_fk_rows  \
# 0      1a  Hash Join (mi_idx.info_type_id = it.id) <- [Se...     2367725
# 1      1c  Hash Join (mi_idx.info_type_id = it.id) <- [Se...     2367725
# 2      2c  Hash Join (mc.company_id = cn.id) <- [Seq Scan...     4958296
# 3      3a  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...     7480087
# 4      3b  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...     7480087
# ..    ...                                                ...         ...
# 100   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...     2367725
# 101   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...     2367725
# 102   33b  Hash Join (mi_idx1.info_type_id = it1.id) <- [...     2367725
# 103   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...     2367725
# 104   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...     2367725
#
#      sq_join_rows    rt_ues  rt_ues_lin  filter_strength_rel  sq_speedup_rel
# 0             250  1.050499    0.992252          9470.900000        0.944553
# 1             250  0.737995    0.701607          9470.900000        0.950693
# 2               7  0.975779    1.028141        708328.000000        1.053662
# 3           14050  2.917895    2.656466           532.390534        0.910405
# 4           14050  1.606580    1.438635           532.390534        0.895464
# ..            ...       ...         ...                  ...             ...
# 100        789155  1.629256    1.583707             3.000329        0.972043
# 101         13726  0.664327    0.589906           172.499271        0.887975
# 102        789155  0.664327    0.589906             3.000329        0.887975
# 103         20658  1.823239    1.756614           114.615403        0.963458
# 104        789155  1.823239    1.756614             3.000329        0.963458
#
# [105 rows x 8 columns]

# %%
df_export = df_ues_wide.drop(
    columns=["query_result_ues_lin",
             "sq_pred",
             "sq_fk_partner",
             "sq_fk_table",
             "sq_join",
             "sq_join_partner",
             "explain_ues_lin"
            ]).rename(
    columns={"query_result_ues": "ues_plan",
             "explain_ues": "ues_explain",
             "sq_fk_rows": "foreign_key_rows",
             "sq_join_rows": "subquery_rows",
             "rt_ues": "runtime_ues",
             "rt_ues_lin": "runtime_ues_linear",
             "sq_speedup_rel": "ues_speedup_rel",
             "sq_speedup_abs": "ues_speedup_abs",
             "query_ues": "query_ues",
             "query_ues_lin": "query_ues_linear",
             "sq_join_duration": "subquery_runtime",
             "sq_join_partner_duration": "subquery_partner_runtime",
             "pruned": "subquery_pruned",
             "node_pruned_ues": "ues_pruned",
             "node_pruned_ues_lin": "ues_linear_pruned"
            })
df_export["tables"] = df_export.query_ues.apply(lambda q: json.dumps([tab.full_name for tab in q.collect_tables()]))
df_export["subquery_tables"] = df_export.subquery.apply(lambda sq: sq.lookup_subquery(sq.join_pred).collect_tables()).apply(lambda sq_tabs: json.dumps([tab.full_name for tab in sq_tabs]))

df_export.ues_explain = df_export.ues_explain.apply(json.dumps)

df_export.to_csv("workloads/job-ues-eval-linearized.csv", index=False)
df_export
# Out:
#                                              query_ues label  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...    1a
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...    1c
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...    2c
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...    3a
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...    3b
# ..                                                 ...   ...
# 100  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33a
# 101  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 102  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33b
# 103  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
# 104  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...   33c
#
#      optimization_time_ues                                           ues_plan  \
# 0                 0.004274  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 1                 0.005587  Hash Join (mi_idx.movie_id = t.id) <- [Hash Jo...
# 2                 0.003486  Hash Join (mc.movie_id = t.id) <- [Hash Join (...
# 3                 0.002976  Hash Join (mk.movie_id = t.id) <- [Hash Join (...
# 4                 0.003484  Hash Join (mk.movie_id = t.id) <- [Hash Join (...
# ..                     ...                                                ...
# 100               0.182369  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 101               0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 102               0.009899  Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# 103               0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
# 104               0.010593  Hash Join (cn1.id = mc1.company_id) <- [~Seq S...
#
#      runtime_ues                                        ues_explain  \
# 0       1.050499  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 1       0.737995  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 2       0.975779  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 3       2.917895  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 4       1.606580  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# ..           ...                                                ...
# 100     1.629256  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 101     0.664327  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 102     0.664327  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 103     1.823239  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 104     1.823239  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                               subquery  subquery_pruned  \
# 0    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            False
# 1    Hash Join (mi_idx.info_type_id = it.id) <- [Se...            False
# 2    Hash Join (mc.company_id = cn.id) <- [Seq Scan...            False
# 3    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...            False
# 4    Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...            False
# ..                                                 ...              ...
# 100  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
# 101  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 102  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
# 103  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 104  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
#
#                                       query_ues_linear  \
# 0    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 1    SELECT COUNT(*) FROM movie_companies AS mc JOI...
# 2    SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
# 3    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# 4    SELECT COUNT(*) FROM movie_info AS mi JOIN tit...
# ..                                                 ...
# 100  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 101  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 102  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 103  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 104  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#      optimization_time_ues_lin  ...  subquery_runtime  \
# 0                     0.004410  ...          0.119231
# 1                     0.004804  ...          0.108347
# 2                     0.002770  ...          0.244117
# 3                     0.002648  ...          0.362651
# 4                     0.004370  ...          0.385987
# ..                         ...  ...               ...
# 100                   0.363256  ...          0.135864
# 101                   0.009747  ...          0.000268
# 102                   0.009747  ...          0.000017
# 103                   0.010535  ...          0.141106
# 104                   0.010535  ...          0.132114
#
#      subquery_partner_runtime  ues_pruned  ues_linear_pruned  \
# 0                    0.885482       False              False
# 1                    0.602376       False              False
# 2                    0.691910       False              False
# 3                    2.517675       False              False
# 4                    1.197622       False              False
# ..                        ...         ...                ...
# 100                  1.467996        True               True
# 101                  0.645468       False              False
# 102                  0.645448       False              False
# 103                  1.671990        True               True
# 104                  1.501128        True               True
#
#      filter_strength_rel  filter_strength_abs  ues_speedup_rel  \
# 0            9470.900000              2367475         0.944553
# 1            9470.900000              2367475         0.950693
# 2          708328.000000              4958289         1.053662
# 3             532.390534              7466037         0.910405
# 4             532.390534              7466037         0.895464
# ..                   ...                  ...              ...
# 100             3.000329              1578570         0.972043
# 101           172.499271              2353999         0.887975
# 102             3.000329              1578570         0.887975
# 103           114.615403              2347067         0.963458
# 104             3.000329              1578570         0.963458
#
#      ues_speedup_abs                                             tables  \
# 0          -0.058247  ["movie_companies", "company_type", "title", "...
# 1          -0.036388  ["movie_companies", "company_type", "title", "...
# 2           0.052362  ["movie_keyword", "keyword", "title", "movie_c...
# 3          -0.261429  ["movie_info", "title", "movie_keyword", "keyw...
# 4          -0.167945  ["movie_info", "title", "movie_keyword", "keyw...
# ..               ...                                                ...
# 100        -0.045549  ["movie_link", "link_type", "title", "kind_typ...
# 101        -0.074421  ["movie_link", "link_type", "title", "kind_typ...
# 102        -0.074421  ["movie_link", "link_type", "title", "kind_typ...
# 103        -0.066625  ["movie_link", "link_type", "title", "kind_typ...
# 104        -0.066625  ["movie_link", "link_type", "title", "kind_typ...
#
#                          subquery_tables
# 0        ["movie_info_idx", "info_type"]
# 1        ["movie_info_idx", "info_type"]
# 2    ["movie_companies", "company_name"]
# 3           ["movie_keyword", "keyword"]
# 4           ["movie_keyword", "keyword"]
# ..                                   ...
# 100      ["movie_info_idx", "info_type"]
# 101      ["movie_info_idx", "info_type"]
# 102      ["movie_info_idx", "info_type"]
# 103      ["movie_info_idx", "info_type"]
# 104      ["movie_info_idx", "info_type"]
#
# [105 rows x 23 columns]

# %% [markdown]
# ## Some sanity checks for the export data set

# %%
df_export.groupby("label")[["label"]].count().rename(columns={"label": "count"}).reset_index().sort_values(by="count", ascending=False)
# Out:
#    label  count
# 58   31c      3
# 56   31a      3
# 39   25c      2
# 61   33a      2
# 57   31b      2
# ..   ...    ...
# 35   23c      1
# 36   24b      1
# 38   25b      1
# 40   26a      1
# 78    8d      1
#
# [79 rows x 2 columns]

# %%
df_export.loc[df_export.filter_strength.isna() & ~df_export.subquery_pruned]
# Out:
# Empty DataFrame
# Columns: [label, query_ues, ues_plan, runtime_ues, ues_explain, subquery, subquery_pruned, query_flat, runtime_flat, foreign_key_rows, rows_after_join, subquery_runtime, subquery_partner_runtime, ues_pruned, flat_pruned, filter_strength, ues_speedup, tables, subquery_tables]
# Index: []

# %%
df_export.loc[df_export.label == "6b"]
# Out:
#    label                                          query_ues  \
# 10    6b  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...
#
#                                              ues_plan  runtime_ues  \
# 10  Hash Join (ci.movie_id = t.id) <- [Hash Join (...     0.536543
#
#                                           ues_explain  \
# 10  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                              subquery  subquery_pruned  \
# 10  Hash Join (ci.person_id = n.id) <- [~Seq Scan~...             True
#
#                                            query_flat  runtime_flat  \
# 10  SELECT COUNT(*) FROM movie_keyword AS mk JOIN ...      2.252002
#
#     foreign_key_rows  rows_after_join  subquery_runtime  \
# 10                 0                0          0.181875
#
#     subquery_partner_runtime  ues_pruned  flat_pruned  filter_strength  \
# 10                  0.349454        True        False              NaN
#
#     ues_speedup                                             tables  \
# 10     4.197244  ["movie_keyword", "keyword", "title", "cast_in...
#
#           subquery_tables
# 10  ["cast_info", "name"]

# %%
df_export.loc[df_export.label == "20b"].iloc[0].query_ues
# Out:
# SELECT COUNT(*) FROM complete_cast AS cc JOIN comp_cast_type AS cct1 ON cct1.kind = 'cast' AND cct1.id = cc.subject_id JOIN comp_cast_type AS cct2 ON cct2.kind LIKE '%complete%' AND cct2.id = cc.status_id JOIN title AS t ON t.production_year > 2000 AND t.id = cc.movie_id JOIN kind_type AS kt ON kt.kind = 'movie' AND kt.id = t.kind_id JOIN (SELECT movie_id FROM movie_keyword AS mk JOIN keyword AS k ON k.keyword IN ('superhero', 'sequel', 'second-part', 'marvel-comics', 'based-on-comic', 'tv-special', 'fight', 'violence') AND k.id = mk.keyword_id) AS t_mk ON t_mk.movie_id = cc.movie_id JOIN (SELECT person_id, movie_id FROM cast_info AS ci JOIN name AS n ON n.name LIKE '%downey%robert%' AND n.id = ci.person_id JOIN char_name AS chn ON chn.name NOT LIKE '%sherlock%' AND (chn.name LIKE '%tony%stark%' OR chn.name LIKE '%iron%man%') AND chn.id = ci.person_role_id) AS t_ci ON t_ci.movie_id = t_mk.movie_id

# %%
print(df_export.loc[df_export.label == "6b"].iloc[0].ues_plan.pretty_print(include_filter=True))
# Out:
# Hash Join (ci.movie_id = t.id)
#   <- [SQ] Hash Join (ci.person_id = n.id)
#     <- [PRUNED] Seq Scan :: cast_info
#     <- Seq Scan :: name (((name)::text ~~ '%downey%robert%'::text))
#   <- Hash Join (t.id = mk.movie_id)
#     <- Seq Scan :: title ((production_year > 2014))
#     <- Hash Join (mk.keyword_id = k.id)
#       <- Seq Scan :: movie_keyword
#       <- Seq Scan :: keyword (((keyword)::text = ANY ('{superhero,sequel,second-part,marvel-comics,based-on-comic,tv-special,fight,violence}'::text[])))

# %%
df_export.loc[df_export.label == "6b"].iloc[0].ues_explain
# Out:
# '[{"Plan": {"Node Type": "Aggregate", "Strategy": "Plain", "Partial Mode": "Simple", "Parallel Aware": false, "Async Capable": false, "Startup Cost": 622730.99, "Total Cost": 622731.0, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 534.419, "Actual Total Time": 535.652, "Actual Rows": 1, "Actual Loops": 1, "Plans": [{"Node Type": "Gather", "Parent Relationship": "Outer", "Parallel Aware": false, "Async Capable": false, "Startup Cost": 179377.81, "Total Cost": 622730.98, "Plan Rows": 1, "Plan Width": 0, "Actual Startup Time": 534.414, "Actual Total Time": 535.647, "Actual Rows": 0, "Actual Loops": 1, "Workers Planned": 2, "Workers Launched": 2, "Single Copy": false, "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 178377.81, "Total Cost": 621730.88, "Plan Rows": 1, "Plan Width": 0, "Actual Startup Time": 531.817, "Actual Total Time": 531.823, "Actual Rows": 0, "Actual Loops": 3, "Inner Unique": false, "Hash Cond": "(ci.movie_id = t.id)", "Workers": [], "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 77320.47, "Total Cost": 520667.86, "Plan Rows": 1511, "Plan Width": 4, "Actual Startup Time": 181.873, "Actual Total Time": 181.875, "Actual Rows": 0, "Actual Loops": 3, "Inner Unique": true, "Hash Cond": "(ci.person_id = n.id)", "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "cast_info", "Alias": "ci", "Startup Cost": 0.0, "Total Cost": 403705.1, "Plan Rows": 15101810, "Plan Width": 8, "Actual Startup Time": 0.0, "Actual Total Time": 0.0, "Actual Rows": 0, "Actual Loops": 0, "Workers": []}, {"Node Type": "Hash", "Parent Relationship": "Inner", "Parallel Aware": true, "Async Capable": false, "Startup Cost": 77318.29, "Total Cost": 77318.29, "Plan Rows": 174, "Plan Width": 4, "Actual Startup Time": 181.862, "Actual Total Time": 181.863, "Actual Rows": 0, "Actual Loops": 3, "Hash Buckets": 1024, "Original Hash Buckets": 1024, "Hash Batches": 1, "Original Hash Batches": 1, "Peak Memory Usage": 0, "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "name", "Alias": "n", "Startup Cost": 0.0, "Total Cost": 77318.29, "Plan Rows": 174, "Plan Width": 4, "Actual Startup Time": 181.83, "Actual Total Time": 181.83, "Actual Rows": 0, "Actual Loops": 3, "Filter": "((name)::text ~~ \'%downey%robert%\'::text)", "Rows Removed by Filter": 1389164, "Workers": []}]}]}, {"Node Type": "Hash", "Parent Relationship": "Inner", "Parallel Aware": true, "Async Capable": false, "Startup Cost": 101057.33, "Total Cost": 101057.33, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 349.542, "Actual Total Time": 349.546, "Actual Rows": 12, "Actual Loops": 3, "Hash Buckets": 1024, "Original Hash Buckets": 1024, "Hash Batches": 1, "Original Hash Batches": 1, "Peak Memory Usage": 104, "Workers": [], "Plans": [{"Node Type": "Hash Join", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Join Type": "Inner", "Startup Cost": 51885.81, "Total Cost": 101057.33, "Plan Rows": 1, "Plan Width": 8, "Actual Startup Time": 274.84, "Actual Total Time": 349.454, "Actual Rows": 12, "Actual Loops": 3, "Inner Unique": false, "Hash Cond": "(t.id = mk.movie_id)", "Workers": [], "Plans": [{"Node Type": "Seq Scan", "Parent Relationship": "Outer", "Parallel Aware": true, "Async Capable": false, "Relation Name": "title", "Alias": "t", "Startup Cost": 0.0, "Total Cost": 49166.29, "Plan Rows": 835, "Plan Width": 4, "Actual Startup Time": 0.272, "Actual Total Time": 77.493, "Actual Rows": 146, "Actual Loops": 3, "Filter": "(production_year > 2014)", "Rows Removed by Filter": 842625, "Workers": []}, {"Node Type": "Hash", "Parent Relationship": "Inne ...

# %%
df_export.loc[df_export.label == "33c"]
# Out:
#     label                                          query_ues  \
# 110   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 111   33c  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
#
#                                               ues_plan  runtime_ues  \
# 110  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.208609
# 111  Hash Join (cn1.id = mc1.company_id) <- [Seq Sc...     1.208609
#
#                                            ues_explain  \
# 110  [{"Plan": {"Node Type": "Aggregate", "Strategy...
# 111  [{"Plan": {"Node Type": "Aggregate", "Strategy...
#
#                                               subquery  subquery_pruned  \
# 110  Hash Join (mi_idx2.info_type_id = it2.id) <- [...            False
# 111  Hash Join (mi_idx1.info_type_id = it1.id) <- [...            False
#
#                                             query_flat  runtime_flat  \
# 110  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.189302
# 111  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...      1.189302
#
#      foreign_key_rows  rows_after_join  subquery_runtime  \
# 110            351960            18374          0.121368
# 111            690018           229962          0.114501
#
#      subquery_partner_runtime  ues_pruned  flat_pruned  filter_strength  \
# 110                  0.695499       False        False        19.155328
# 111                  0.564965       False        False         3.000574
#
#      ues_speedup                                             tables  \
# 110     0.984025  ["movie_link", "link_type", "title", "title", ...
# 111     0.984025  ["movie_link", "link_type", "title", "title", ...
#
#                      subquery_tables
# 110  ["movie_info_idx", "info_type"]
# 111  ["movie_info_idx", "info_type"]

# %%
df_export.loc[df_export.label == "33c"].iloc[0].query_ues
# Out:
# SELECT COUNT(*) FROM movie_link AS ml JOIN link_type AS lt ON lt.link IN ('sequel', 'follows', 'followed by') AND lt.id = ml.link_type_id JOIN title AS t2 ON t2.production_year BETWEEN 2000 AND 2010 AND t2.id = ml.linked_movie_id JOIN title AS t1 ON t1.id = ml.movie_id JOIN kind_type AS kt1 ON kt1.kind IN ('tv series', 'episode') AND kt1.id = t1.kind_id JOIN kind_type AS kt2 ON kt2.kind IN ('tv series', 'episode') AND kt2.id = t2.kind_id JOIN (SELECT movie_id FROM movie_info_idx AS mi_idx1 JOIN info_type AS it1 ON it1.info = 'rating' AND it1.id = mi_idx1.info_type_id) AS t_mi_idx1 ON t_mi_idx1.movie_id = ml.movie_id JOIN (SELECT movie_id FROM movie_info_idx AS mi_idx2 JOIN info_type AS it2 ON it2.info = 'rating' AND it2.id = mi_idx2.info_type_id AND mi_idx2.info < '3.5') AS t_mi_idx2 ON t_mi_idx2.movie_id = ml.linked_movie_id JOIN movie_companies AS mc2 ON mc2.movie_id = ml.linked_movie_id JOIN company_name AS cn2 ON cn2.id = mc2.company_id JOIN movie_companies AS mc1 ON mc1.movie_id = ml.movie_id JOIN company_name AS cn1 ON cn1.country_code <> '[us]' AND cn1.id = mc1.company_id

# %%
print(df_export.loc[df_export.label == "33c"].iloc[0].ues_plan.pretty_print(include_filter=True))
# Out:
# Hash Join (cn1.id = mc1.company_id)
#   <- Seq Scan :: company_name (((country_code)::text <> '[us]'::text))
#   <- Hash Join (mc1.movie_id = t1.id)
#     <- Seq Scan :: movie_companies
#     <- Hash Join (cn2.id = mc2.company_id)
#       <- Seq Scan :: company_name
#       <- Hash Join (mc2.movie_id = t2.id)
#         <- Seq Scan :: movie_companies
#         <- Hash Join (mi_idx2.movie_id = t2.id)
#           <- [SQ] Hash Join (mi_idx2.info_type_id = it2.id)
#             <- Seq Scan :: movie_info_idx (((info)::text < '3.5'::text))
#             <- Seq Scan :: info_type (((info)::text = 'rating'::text))
#           <- Hash Join (mi_idx1.movie_id = t1.id)
#             <- [SQ] Hash Join (mi_idx1.info_type_id = it1.id)
#               <- Seq Scan :: movie_info_idx
#               <- Seq Scan :: info_type (((info)::text = 'rating'::text))
#             <- Hash Join (t2.kind_id = kt2.id)
#               <- Hash Join (t1.kind_id = kt1.id)
#                 <- Merge Join (t1.id = ml.movie_id)
#                   <- Index Scan :: title
#                   <- Hash Join (ml.linked_movie_id = t2.id)
#                     <- Hash Join (ml.link_type_id = lt.id)
#                       <- Seq Scan :: movie_link
#                       <- Seq Scan :: link_type (((link)::text = ANY ('{sequel,follows,"followed by"}'::text[])))
#                     <- Seq Scan :: title (((production_year >= 2000) AND (production_year <= 2010)))
#                 <- Seq Scan :: kind_type (((kind)::text = ANY ('{"tv series",episode}'::text[])))
#               <- Seq Scan :: kind_type (((kind)::text = ANY ('{"tv series",episode}'::text[])))
