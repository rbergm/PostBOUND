# %% [markdown]
# # UES IndexNestedLoopJoin workload

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import numpy as np
import pandas as pd

from transform import mosp
from postgres import explain
from analysis import selection

# %%
df_base_full = pd.read_csv("workloads/job-ues-results-base.csv")

df_idxnlj_base_full = pd.read_csv("workloads/job-ues-results-idxnlj.csv")
df_idxnlj_allnlj_full = pd.read_csv("workloads/job-ues-results-idxnlj-allnlj.csv")
df_idxnlj_pkidx_full = pd.read_csv("workloads/job-ues-results-idxnlj-pkdix.csv")
df_idxnlj_allnlj_pkidx_full = pd.read_csv("workloads/job-ues-results-idxnlj-allnlj-pkdix.csv")

# %%
df_base = selection.best_query_repetition(df_base_full, "label", performance_col="query_rt_total")
df_base["workload"] = "ues"

df_idxnlj_base = selection.best_query_repetition(df_idxnlj_base_full, "label", performance_col="query_rt_total")
df_idxnlj_base["workload"] = "ues_idxnlj"
df_idxnlj_base["nlj_scope"] = "inner"
df_idxnlj_base["indexed"] = "foreign_key"

df_idxnlj_allnlj = selection.best_query_repetition(df_idxnlj_allnlj_full, "label", performance_col="query_rt_total")
df_idxnlj_allnlj["workload"] = "ues_idxnlj"
df_idxnlj_allnlj["nlj_scope"] = "full"
df_idxnlj_allnlj["indexed"] = "foreign_key"

df_idxnlj_pkidx = selection.best_query_repetition(df_idxnlj_pkidx_full, "label", performance_col="query_rt_total")
df_idxnlj_pkidx["workload"] = "ues_idxnlj"
df_idxnlj_pkidx["nlj_scope"] = "inner"
df_idxnlj_pkidx["indexed"] = "primary_key"

df_idxnlj_allnlj_pkidx = selection.best_query_repetition(df_idxnlj_allnlj_pkidx_full, "label", performance_col="query_rt_total")
df_idxnlj_allnlj_pkidx["workload"] = "ues_idxnlj"
df_idxnlj_allnlj_pkidx["nlj_scope"] = "full"
df_idxnlj_allnlj_pkidx["indexed"] = "primary_key"

df_idxnlj = pd.concat([df_idxnlj_base, df_idxnlj_allnlj, df_idxnlj_pkidx, df_idxnlj_allnlj_pkidx])

# %%
df = pd.concat([df_base, df_idxnlj]).reset_index(drop=True).rename(columns={"query_rt_total": "rt_total"})

# %%
df_base_full.groupby("run").query_rt_total.sum()
# Out:
# run
# 1    295.824442
# 2    281.237423
# 3    278.699711
# 4    274.818035
# 5    275.428677
# Name: query_rt_total, dtype: float64

# %%
df_idxnlj_base_full.groupby("run").query_rt_total.sum()
# Out:
# run
# 1    290.649480
# 2    267.113291
# 3    267.614191
# 4    269.312999
# 5    268.451439
# Name: query_rt_total, dtype: float64

# %%
df_idxnlj_allnlj_full.groupby("run").query_rt_total.sum()
# Out:
# run
# 1    316.899507
# 2    294.063401
# 3    290.167805
# 4    293.375298
# 5    290.071217
# Name: query_rt_total, dtype: float64

# %%
df_idxnlj_pkidx_full.groupby("run").query_rt_total.sum()
# Out:
# run
# 1    297.551554
# 2    277.121557
# 3    273.854234
# 4    272.044943
# 5    275.510750
# Name: query_rt_total, dtype: float64

# %%
df_idxnlj_allnlj_pkidx_full.groupby("run").query_rt_total.sum()
# Out:
# run
# 1    319.239451
# 2    297.132287
# 3    296.387338
# 4    293.483264
# 5    294.063647
# Name: query_rt_total, dtype: float64

# %%
df["query"] = df["query"].apply(mosp.MospQuery.parse)

# %%
df["query_result"] = df["query_result"].apply(json.loads)

# %%
df["explain_output"] = df.apply(lambda row: explain.parse_explain_analyze(row["query"], row["query_result"]), axis="columns")
# Out:
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:481: UserWarning: Unknown node type: Hash
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:481: UserWarning: Unknown node type: Gather
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:481: UserWarning: Unknown node type: Aggregate
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:481: UserWarning: Unknown node type: Sort
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:481: UserWarning: Unknown node type: Gather Merge
#   warnings.warn("Unknown node type: {}".format(node_type))
# /home/rico/Projekte/Uni/DiplomArbeit-QueryOpt/ues/postgres/explain.py:481: UserWarning: Unknown node type: Materialize
#   warnings.warn("Unknown node type: {}".format(node_type))

# %%
df["n_subqueries"] = df["query"].apply(lambda q: len(q.subqueries()))

# %%
subqueries = df.loc[df.n_subqueries > 0]
ues_queries = subqueries.loc[subqueries.workload == "ues"].copy()
idxnlj_queries = subqueries.loc[subqueries.workload != "ues"].copy()

# %%
ues_queries.drop(columns=["run", "workload", "query_hint", "nlj_scope", "indexed"], inplace=True, errors="ignore")
ues_queries["subquery_explain"] = ues_queries["explain_output"].apply(lambda p: p.extract_subqueries())
ues_queries = ues_queries.explode("subquery_explain")
ues_queries["subquery_predicate"] = ues_queries["subquery_explain"].apply(lambda sq: sq.join_pred)
ues_queries["subquery_duration"] = ues_queries["subquery_explain"].apply(lambda sq: sq.exec_time)
ues_queries["subquery_pruned"] = ues_queries["subquery_explain"].apply(lambda sq: sq.pruned)

# %%
idxnlj_queries.drop(columns=["query", "run", "workload", "n_subqueries"], inplace=True, errors="ignore")
idxnlj_queries["subquery_explain"] = idxnlj_queries["explain_output"].apply(lambda p: p.extract_subqueries())
idxnlj_queries = idxnlj_queries.explode("subquery_explain")
idxnlj_queries["subquery_predicate"] = idxnlj_queries["subquery_explain"].apply(lambda sq: sq.join_pred)
idxnlj_queries["subquery_duration"] = idxnlj_queries["subquery_explain"].apply(lambda sq: sq.exec_time)
idxnlj_queries["subquery_pruned"] = idxnlj_queries["subquery_explain"].apply(lambda sq: sq.pruned)

# %%
def count_total_scanned_tuples(row, *, scan_ops=[explain.QueryNode.SEQ_SCAN]):
    if row.subquery_pruned_idxnlj:
        return 0
    scan_nodes = [row.subquery_explain_idxnlj.lookup_scan(tab) for tab in row.subquery.subquery.collect_tables()]
    matching_tables = [tab for tab in scan_nodes if tab.node in scan_ops]
    return sum(tab.incoming_rows(fallback_live=True) for tab in matching_tables)

# %%
subquery_features = idxnlj_queries.merge(ues_queries, how="inner", on=["label", "subquery_predicate"], suffixes=("_idxnlj", "_ues"))
subquery_features["subquery"] = subquery_features.apply(lambda row: row["query"].lookup_subquery(row["subquery_predicate"]), axis="columns")
subquery_features["subquery_outgoing_tuples"] = subquery_features.subquery.apply(lambda sq: sq.subquery.count_result_tuples())
subquery_features["subquery_idxlookup_tuples"] = subquery_features.apply(count_total_scanned_tuples, axis="columns", scan_ops=[explain.QueryNode.IDX_SCAN, explain.QueryNode.IDX_ONLY_SCAN])
subquery_features["subquery_scanned_tuples"] = subquery_features.apply(count_total_scanned_tuples, axis="columns", scan_ops=[explain.QueryNode.SEQ_SCAN, explain.QueryNode.BMP_SCAN])
subquery_features["n_subquery_joins"] = subquery_features.subquery.apply(lambda sq: len(sq.subquery.joins()))

# %%
df_export = subquery_features[
    ["label", "query", "query_hint", "n_subquery_joins",
     "query_result_ues", "rt_total_ues", "subquery_duration_ues", "subquery_pruned_ues",
     "nlj_scope", "indexed", "query_result_idxnlj", "rt_total_idxnlj", "subquery_duration_idxnlj", "subquery_pruned_idxnlj",
     "subquery_outgoing_tuples", "subquery_idxlookup_tuples", "subquery_scanned_tuples"
    ]
].copy()

df_export["query_result_ues"] = df_export["query_result_ues"].apply(json.dumps)
df_export["query_result_idxnlj"] = df_export["query_result_idxnlj"].apply(json.dumps)

df_export.to_csv("workloads/job-ues-features-idxnlj.csv", index=False)
df_export
# Out:
#     label                                              query  \
# 0     11a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 1     11a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 2     11a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 3     11a  SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# 4     11b  SELECT COUNT(*) FROM movie_companies AS mc JOI...
# ..    ...                                                ...
# 423    8c  SELECT COUNT(*) FROM aka_name AS a1 JOIN name ...
# 424    8d  SELECT COUNT(*) FROM aka_name AS an1 JOIN name...
# 425    8d  SELECT COUNT(*) FROM aka_name AS an1 JOIN name...
# 426    8d  SELECT COUNT(*) FROM aka_name AS an1 JOIN name...
# 427    8d  SELECT COUNT(*) FROM aka_name AS an1 JOIN name...
#
#                                             query_hint  n_subquery_joins  \
# 0           /*+\nIndexOnlyScan(mk)\nNestLoop(mk k)\n*/                 1
# 1           /*+\nIndexOnlyScan(mk)\nNestLoop(mk k)\n*/                 1
# 2            /*+\nIndexOnlyScan(k)\nNestLoop(mk k)\n*/                 1
# 3            /*+\nIndexOnlyScan(k)\nNestLoop(mk k)\n*/                 1
# 4    /*+\nIndexOnlyScan(ml)\nIndexOnlyScan(mk)\nNes...                 1
# ..                                                 ...               ...
# 423  /*+\nIndexOnlyScan(rt)\nIndexOnlyScan(t)\nNest...                 2
# 424        /*+\nIndexOnlyScan(ci)\nNestLoop(ci rt)\n*/                 2
# 425  /*+\nIndexOnlyScan(ci)\nIndexOnlyScan(t)\nNest...                 2
# 426        /*+\nIndexOnlyScan(rt)\nNestLoop(ci rt)\n*/                 2
# 427  /*+\nIndexOnlyScan(rt)\nIndexOnlyScan(t)\nNest...                 2
#
#                                       query_result_ues  rt_total_ues  \
# 0    [{"Plan": {"Node Type": "Aggregate", "Strategy...      0.098920
# 1    [{"Plan": {"Node Type": "Aggregate", "Strategy...      0.098920
# 2    [{"Plan": {"Node Type": "Aggregate", "Strategy...      0.098920
# 3    [{"Plan": {"Node Type": "Aggregate", "Strategy...      0.098920
# 4    [{"Plan": {"Node Type": "Aggregate", "Strategy...      0.227532
# ..                                                 ...           ...
# 423  [{"Plan": {"Node Type": "Aggregate", "Strategy...      8.525333
# 424  [{"Plan": {"Node Type": "Aggregate", "Strategy...      5.657469
# 425  [{"Plan": {"Node Type": "Aggregate", "Strategy...      5.657469
# 426  [{"Plan": {"Node Type": "Aggregate", "Strategy...      5.657469
# 427  [{"Plan": {"Node Type": "Aggregate", "Strategy...      5.657469
#
#      subquery_duration_ues  subquery_pruned_ues nlj_scope      indexed  \
# 0                 0.000000                 True     inner  foreign_key
# 1                 0.000000                 True      full  foreign_key
# 2                 0.000000                 True     inner  primary_key
# 3                 0.000000                 True      full  primary_key
# 4                 0.000000                 True     inner  foreign_key
# ..                     ...                  ...       ...          ...
# 423               4.857518                False      full  primary_key
# 424               3.853126                False     inner  foreign_key
# 425               3.853126                False      full  foreign_key
# 426               3.853126                False     inner  primary_key
# 427               3.853126                False      full  primary_key
#
#                                    query_result_idxnlj  rt_total_idxnlj  \
# 0    [{"Plan": {"Node Type": "Aggregate", "Strategy...         0.124898
# 1    [{"Plan": {"Node Type": "Aggregate", "Strategy...         0.127996
# 2    [{"Plan": {"Node Type": "Aggregate", "Strategy...         0.126593
# 3    [{"Plan": {"Node Type": "Aggregate", "Strategy...         0.125931
# 4    [{"Plan": {"Node Type": "Aggregate", "Strategy...         0.326768
# ..                                                 ...              ...
# 423  [{"Plan": {"Node Type": "Aggregate", "Strategy...        16.263859
# 424  [{"Plan": {"Node Type": "Aggregate", "Strategy...         2.594441
# 425  [{"Plan": {"Node Type": "Aggregate", "Strategy...         2.568197
# 426  [{"Plan": {"Node Type": "Aggregate", "Strategy...         2.590833
# 427  [{"Plan": {"Node Type": "Aggregate", "Strategy...         2.445849
#
#      subquery_duration_idxnlj  subquery_pruned_idxnlj  \
# 0                    0.000000                    True
# 1                    0.000000                    True
# 2                    0.000000                    True
# 3                    0.000000                    True
# 4                    0.000000                    True
# ..                        ...                     ...
# 423                 10.717574                   False
# 424                  0.823238                   False
# 425                  1.183267                   False
# 426                  0.818465                   False
# 427                  1.066421                   False
#
#      subquery_outgoing_tuples  subquery_idxlookup_tuples  \
# 0                       11404                          0
# 1                       11404                          0
# 2                       11404                          0
# 3                       11404                          0
# 4                       11404                          0
# ..                        ...                        ...
# 423                   5175636                   68211953
# 424                    518182                   63475827
# 425                    518182                   68211941
# 426                    518182                   63475839
# 427                    518182                   68211953
#
#      subquery_scanned_tuples
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 423                        0
# 424                  4736126
# 425                       12
# 426                  4736114
# 427                        0
#
# [428 rows x 17 columns]

# %% [markdown]
# ---
#
# ## Actual Rows shenanigans

# %%
regressions = subquery_features.copy()
regressions["subquery_rows_ues"] = regressions.subquery_explain_ues.apply(lambda sq: sq.proc_rows)
regressions["subquery_rows_idxnlj"] = regressions.subquery_explain_idxnlj.apply(lambda sq: sq.proc_rows)
regressions["subquery_operator_ues"] = regressions.subquery_explain_ues.apply(lambda sq: sq.node)
regressions["subquery_operator_idxnlj"] = regressions.subquery_explain_idxnlj.apply(lambda sq: sq.node)
regressions = regressions[(regressions["subquery_rows_ues"] != regressions["subquery_rows_idxnlj"]) & ~regressions.subquery_pruned_ues & ~regressions.subquery_pruned_idxnlj]
regressions[["label", "subquery_explain_ues", "subquery_explain_idxnlj", "subquery_rows_ues", "subquery_rows_idxnlj"]]
# Out:
#     label                               subquery_explain_ues  \
# 28    13a  Hash Join (mi.info_type_id = it2.id) <- [Seq S...
# 29    13a  Hash Join (mi.info_type_id = it2.id) <- [Seq S...
# 30    13a  Hash Join (mi.info_type_id = it2.id) <- [Seq S...
# 31    13a  Hash Join (mi.info_type_id = it2.id) <- [Seq S...
# 32    13b  Hash Join (mc.company_id = cn.id) <- [Hash Joi...
# ..    ...                                                ...
# 389    4c  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...
# 390    4c  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...
# 391    4c  Hash Join (mk.keyword_id = k.id) <- [Seq Scan ...
# 425    8d  Hash Join (t.id = ci.movie_id) <- [Seq Scan ::...
# 427    8d  Hash Join (t.id = ci.movie_id) <- [Seq Scan ::...
#
#                                subquery_explain_idxnlj  subquery_rows_ues  \
# 28   Nested Loop (mi.info_type_id = it2.id) <- [Seq...            5433156
# 29   Nested Loop (mi.info_type_id = it2.id) <- [Seq...            5433156
# 30   Nested Loop (mi.info_type_id = it2.id) <- [Ind...            5433156
# 31   Nested Loop (mi.info_type_id = it2.id) <- [Ind...            5433156
# 32   Hash Join (mc.company_id = cn.id) <- [Nested L...            1320120
# ..                                                 ...                ...
# 389  Nested Loop (mk.keyword_id = k.id) <- [Seq Sca...              14049
# 390  Nested Loop (mk.keyword_id = k.id) <- [Index S...              14049
# 391  Nested Loop (mk.keyword_id = k.id) <- [Index S...              14049
# 425  Nested Loop (t.id = ci.movie_id) <- [Nested Lo...             518181
# 427  Nested Loop (t.id = ci.movie_id) <- [Nested Lo...             518181
#
#      subquery_rows_idxnlj
# 28                5433157
# 29                5433157
# 30                5433157
# 31                5433157
# 32                1320121
# ..                    ...
# 389                 14050
# 390                 14050
# 391                 14050
# 425                518182
# 427                518182
#
# [100 rows x 5 columns]

# %%
regressions["subquery_row_ratio"] = (np.max([regressions["subquery_rows_ues"], regressions["subquery_rows_idxnlj"]], axis=0)
                                     /
                                     np.min([regressions["subquery_rows_ues"], regressions["subquery_rows_idxnlj"]], axis=0))

# %% [markdown]
# All different tuples counts are fractions of full numbers (we need more complicated logic here, b/c tuple counts can vary slightly as they are averaged)

# %%
regressions[(regressions["subquery_row_ratio"] % 1 > 0.05) & (regressions["subquery_row_ratio"] % 1 < 0.95)]
# Out:
# Empty DataFrame
# Columns: [label, query_result_idxnlj, rt_total_idxnlj, query_hint, nlj_scope, indexed, explain_output_idxnlj, subquery_explain_idxnlj, subquery_predicate, subquery_duration_idxnlj, subquery_pruned_idxnlj, query, query_result_ues, rt_total_ues, explain_output_ues, n_subqueries, subquery_explain_ues, subquery_duration_ues, subquery_pruned_ues, subquery, subquery_outgoing_tuples, subquery_idxlookup_tuples, subquery_scanned_tuples, n_subquery_joins, subquery_rows_ues, subquery_rows_idxnlj, subquery_operator_ues, subquery_operator_idxnlj, subquery_row_ratio]
# Index: []
#
# [0 rows x 29 columns]

# %%
regressions[regressions["subquery_explain_ues"].apply(lambda sq: sq.node) == regressions["subquery_explain_idxnlj"].apply(lambda sq: sq.node)][
    ["label", "subquery_explain_ues", "subquery_explain_idxnlj", "subquery_rows_ues", "subquery_rows_idxnlj", "subquery_row_ratio"]
]
# Out:
#    label                               subquery_explain_ues  \
# 32   13b  Hash Join (mc.company_id = cn.id) <- [Hash Joi...
# 33   13b  Hash Join (mc.company_id = cn.id) <- [Hash Joi...
# 44   13d  Hash Join (mc.company_id = cn.id) <- [Hash Joi...
# 45   13d  Hash Join (mc.company_id = cn.id) <- [Hash Joi...
#
#                               subquery_explain_idxnlj  subquery_rows_ues  \
# 32  Hash Join (mc.company_id = cn.id) <- [Nested L...            1320120
# 33  Hash Join (mc.company_id = cn.id) <- [Nested L...            1320120
# 44  Hash Join (mc.company_id = cn.id) <- [Nested L...            1320120
# 45  Hash Join (mc.company_id = cn.id) <- [Nested L...            1320120
#
#     subquery_rows_idxnlj  subquery_row_ratio
# 32               1320121            1.000001
# 33               1320121            1.000001
# 44               1320121            1.000001
# 45               1320121            1.000001

# %%
regressions.subquery_row_ratio.min(), regressions.subquery_row_ratio.max()
# Out:
# (1.000000184055087, 13726.0)

# %%
regressions.loc[regressions.subquery_row_ratio > 1.01][
    ["label", "subquery_explain_ues", "subquery_explain_idxnlj", "subquery_operator_ues", "subquery_operator_idxnlj", "subquery_rows_ues", "subquery_rows_idxnlj", "subquery_row_ratio"]
]
# Out:
#     label                               subquery_explain_ues  \
# 348   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 349   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 350   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 351   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 354   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 355   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 360   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 361   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 362   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 363   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 364   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 365   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 366   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 367   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
#
#                                subquery_explain_idxnlj subquery_operator_ues  \
# 348  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 349  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 350  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 351  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 354  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 355  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 360  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 361  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 362  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 363  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 364  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 365  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 366  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 367  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
#
#     subquery_operator_idxnlj  subquery_rows_ues  subquery_rows_idxnlj  \
# 348    QueryNode.NESTED_LOOP             789156               2367465
# 349    QueryNode.NESTED_LOOP             789156               2367465
# 350    QueryNode.NESTED_LOOP             789156               2367465
# 351    QueryNode.NESTED_LOOP             789156               2367465
# 354    QueryNode.NESTED_LOOP                  1                 13726
# 355    QueryNode.NESTED_LOOP                  1                 13726
# 360    QueryNode.NESTED_LOOP              20658                 61974
# 361    QueryNode.NESTED_LOOP              20658                 61974
# 362    QueryNode.NESTED_LOOP              20658                 61974
# 363    QueryNode.NESTED_LOOP              20658                 61974
# 364    QueryNode.NESTED_LOOP             789156               2367465
# 365    QueryNode.NESTED_LOOP             789156               2367465
# 366    QueryNode.NESTED_LOOP             789156               2367465
# 367    QueryNode.NESTED_LOOP             789156               2367465
#
#      subquery_row_ratio
# 348            2.999996
# 349            2.999996
# 350            2.999996
# 351            2.999996
# 354        13726.000000
# 355        13726.000000
# 360            3.000000
# 361            3.000000
# 362            3.000000
# 363            3.000000
# 364            2.999996
# 365            2.999996
# 366            2.999996
# 367            2.999996

# %%
regressions.loc[(regressions.subquery_row_ratio > 1.01) & ~regressions.subquery_pruned_ues & ~regressions.subquery_pruned_idxnlj][
    ["label", "subquery_explain_ues", "subquery_explain_idxnlj", "subquery_operator_ues", "subquery_operator_idxnlj", "subquery_rows_ues", "subquery_rows_idxnlj", "subquery_row_ratio"]
]
# Out:
#     label                               subquery_explain_ues  \
# 348   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 349   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 350   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 351   33a  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 354   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 355   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 360   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 361   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 362   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 363   33c  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 364   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 365   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 366   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
# 367   33c  Hash Join (mi_idx1.info_type_id = it1.id) <- [...
#
#                                subquery_explain_idxnlj subquery_operator_ues  \
# 348  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 349  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 350  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 351  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 354  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 355  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 360  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 361  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 362  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 363  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 364  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 365  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 366  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
# 367  Nested Loop (mi_idx1.info_type_id = it1.id) <-...   QueryNode.HASH_JOIN
#
#     subquery_operator_idxnlj  subquery_rows_ues  subquery_rows_idxnlj  \
# 348    QueryNode.NESTED_LOOP             789156               2367465
# 349    QueryNode.NESTED_LOOP             789156               2367465
# 350    QueryNode.NESTED_LOOP             789156               2367465
# 351    QueryNode.NESTED_LOOP             789156               2367465
# 354    QueryNode.NESTED_LOOP                  1                 13726
# 355    QueryNode.NESTED_LOOP                  1                 13726
# 360    QueryNode.NESTED_LOOP              20658                 61974
# 361    QueryNode.NESTED_LOOP              20658                 61974
# 362    QueryNode.NESTED_LOOP              20658                 61974
# 363    QueryNode.NESTED_LOOP              20658                 61974
# 364    QueryNode.NESTED_LOOP             789156               2367465
# 365    QueryNode.NESTED_LOOP             789156               2367465
# 366    QueryNode.NESTED_LOOP             789156               2367465
# 367    QueryNode.NESTED_LOOP             789156               2367465
#
#      subquery_row_ratio
# 348            2.999996
# 349            2.999996
# 350            2.999996
# 351            2.999996
# 354        13726.000000
# 355        13726.000000
# 360            3.000000
# 361            3.000000
# 362            3.000000
# 363            3.000000
# 364            2.999996
# 365            2.999996
# 366            2.999996
# 367            2.999996

# %%
len(regressions.loc[(regressions.subquery_row_ratio > 1.01) &
                    (regressions.explain_output_ues.apply(explain.PlanNode.any_pruned) |
                    regressions.explain_output_idxnlj.apply(explain.PlanNode.any_pruned))])
# Out:
# 12

# %%
len(subquery_features.loc[subquery_features.explain_output_ues.apply(explain.PlanNode.any_pruned) | subquery_features.explain_output_idxnlj.apply(explain.PlanNode.any_pruned)])
# Out:
# 260

# %%
regressions.loc[(regressions.subquery_row_ratio > 1.01) &
                    ~regressions.explain_output_ues.apply(explain.PlanNode.any_pruned) &
                    ~regressions.explain_output_idxnlj.apply(explain.PlanNode.any_pruned)][
    ["label", "subquery_explain_ues", "subquery_explain_idxnlj", "subquery_operator_ues", "subquery_operator_idxnlj", "subquery_rows_ues", "subquery_rows_idxnlj", "subquery_row_ratio"]
]
# Out:
#     label                               subquery_explain_ues  \
# 354   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# 355   33b  Hash Join (mi_idx2.info_type_id = it2.id) <- [...
#
#                                subquery_explain_idxnlj subquery_operator_ues  \
# 354  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
# 355  Nested Loop (mi_idx2.info_type_id = it2.id) <-...   QueryNode.HASH_JOIN
#
#     subquery_operator_idxnlj  subquery_rows_ues  subquery_rows_idxnlj  \
# 354    QueryNode.NESTED_LOOP                  1                 13726
# 355    QueryNode.NESTED_LOOP                  1                 13726
#
#      subquery_row_ratio
# 354             13726.0
# 355             13726.0

# %%
r = regressions.loc[(regressions.subquery_row_ratio > 1.01) &
                    ~regressions.explain_output_ues.apply(explain.PlanNode.any_pruned) &
                    ~regressions.explain_output_idxnlj.apply(explain.PlanNode.any_pruned)].iloc[0]
r
# Out:
# label                                                                      33b
# query_result_idxnlj          [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# rt_total_idxnlj                                                       0.853289
# query_hint                   /*+\nIndexOnlyScan(it1)\nIndexOnlyScan(it2)\nN...
# nlj_scope                                                                inner
# indexed                                                            primary_key
# explain_output_idxnlj        Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# subquery_explain_idxnlj      Nested Loop (mi_idx2.info_type_id = it2.id) <-...
# subquery_predicate                             (mi_idx2.info_type_id = it2.id)
# subquery_duration_idxnlj                                              0.139529
# subquery_pruned_idxnlj                                                   False
# query                        SELECT COUNT(*) FROM movie_link AS ml JOIN lin...
# query_result_ues             [{'Plan': {'Node Type': 'Aggregate', 'Strategy...
# rt_total_ues                                                          0.682805
# explain_output_ues           Hash Join (mc1.company_id = cn1.id) <- [Hash J...
# n_subqueries                                                                 2
# subquery_explain_ues         Hash Join (mi_idx2.info_type_id = it2.id) <- [...
# subquery_duration_ues                                                 0.000281
# subquery_pruned_ues                                                      False
# subquery                     JOIN (SELECT movie_id FROM movie_info_idx AS m...
# subquery_outgoing_tuples                                                 13726
# subquery_idxlookup_tuples                                                  113
# subquery_scanned_tuples                                                2367725
# n_subquery_joins                                                             1
# subquery_rows_ues                                                            1
# subquery_rows_idxnlj                                                     13726
# subquery_operator_ues                                      QueryNode.HASH_JOIN
# subquery_operator_idxnlj                                 QueryNode.NESTED_LOOP
# subquery_row_ratio                                                     13726.0
# Name: 354, dtype: object

# %%
print(r.subquery_explain_ues.pretty_print())
# Out:
# [SQ] Hash Join (mi_idx2.info_type_id = it2.id)
#   <- Seq Scan :: movie_info_idx
#   <- Seq Scan :: info_type

# %%
print(r.subquery_explain_idxnlj.pretty_print())
# Out:
# [SQ] Nested Loop (mi_idx2.info_type_id = it2.id)
#   <- Index Scan :: info_type
#   <- Bitmap Scan (virtual) :: movie_info_idx
